# %%
#Import packages
import os #Allows us to get operating system information in python.
#In artemis video, he did not import os package

#Data Handling
import pandas as pd, numpy as np

#Time
import time

#Plotting
import matplotlib.pyplot as plt, seaborn as sns, scipy.stats, pylab

#Saving data
import pickle

#train and test split
from sklearn.model_selection import train_test_split

#Scalers
from sklearn import preprocessing

#TomekLinks and RandomUnderSampler
from imblearn.under_sampling import TomekLinks, RandomUnderSampler

#Hyperparameter optimization
import optuna

#Metrics
from sklearn.metrics import f1_score, balanced_accuracy_score, recall_score, roc_auc_score

#General Management
import gc as gc
gc.enable()
from joblib import dump, load
from warnings import filterwarnings

#Notebook configurations
filterwarnings('ignore')

# %%
#MODELS
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB

# %%
f = open('CCF_ProcessedData.pckl','rb')
pickle_list = pickle.load(f)
f.close()

#pickle_list = [tomek_modeling_data, y, rus_tomek_modeling_data, y2]

tomek_modeling_data = pickle_list[0]
y = pickle_list[1]
rus_tomek_modeling_data = pickle_list[2]
y2 = pickle_list[3]
test = pickle_list[4]

# %%
#TEST
#print(tomek_modeling_data.head())
#print(rus_tomek_modeling_data.head())

#Double check column values before moving forward

#tomek_modeling_data - GOOD!
# for col in tomek_modeling_data.columns:
#     print(col, tomek_modeling_data[col].dtype) 
    
#rus_tomek_modeling_data - GOOD!
# for col in rus_tomek_modeling_data.columns:
#     print(col, rus_tomek_modeling_data[col].dtype)

# modeling_cat_cols = [col for col in modeling_data.columns if col not in ['Age', 'Flight Distance', 'Departure Delay in Minutes','Arrival Delay in Minutes', 'satisfaction']]
# t_mcol = [col for col in tomek_modeling_data.columns if col not in ['amount_4root','oldbalanceOrig_4root','newbalanceOrig_4root','oldbalanceDest_4root','newbalanceDest_4root']]
# t_rus_mcol = [col for col in rus_tomek_modeling_data.columns if col not in ['amount_4root','oldbalanceOrig_4root','newbalanceOrig_4root','oldbalanceDest_4root','newbalanceDest_4root']]

# # for col in modeling_cat_cols:
# #     modeling_data[col] = modeling_data[col].astype('category')

# #Tomek
# for col in t_mcol:
#     tomek_modeling_data[col] = tomek_modeling_data[col].astype('category')
    
# #Tomek + RUS
# for col in t_rus_mcol:
#     rus_tomek_modeling_data[col] = rus_tomek_modeling_data[col].astype('category')
# Out:
#    isFraud
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# # MODELING

# %%
#tomek_modeling_data & y
Xtrain_tomek, Xdev_tomek, ytrain_tomek, ydev_tomek = train_test_split(tomek_modeling_data, y, stratify=y, test_size=0.1, random_state=5)

#rus_tomek_modeling_data & y2
Xtrain_rus, Xdev_rus, ytrain_rus, ydev_rus = train_test_split(rus_tomek_modeling_data, y2, stratify=y2, test_size=0.3, random_state=5)

# %%
#SAVE THE VARIABLES ABOVE SO WE DO NOT NEED TO RE-RUN AND CAN CALL
#FROM THE APPROPRIATE GET_DATA FUNCTION
pickle_list1 = [Xtrain_tomek, Xdev_tomek, ytrain_tomek, ydev_tomek]
pickle_list2 = [Xtrain_rus, Xdev_rus, ytrain_rus, ydev_rus]
f1 = open('tomek_data.pckl','wb')
f2 = open('rus_data.pckl','wb')
pickle.dump(pickle_list1,f1)
pickle.dump(pickle_list2,f2)
f1.close()
f2.close()

# %%
#List of the 13 classifiers we will test
classifiers = [XGBClassifier(random_state=1,categorical_features=True),
               LGBMClassifier(random_state=1,is_unbalance=True),
               RandomForestClassifier(random_state=1),
               ExtraTreesClassifier(random_state=1),
               GradientBoostingClassifier(random_state=1),
               DecisionTreeClassifier(random_state=1),
               ExtraTreeClassifier(random_state=1),
               LogisticRegression(random_state=1),
               RidgeClassifier(random_state=1),
               SGDClassifier(random_state=1),
               KNeighborsClassifier(n_neighbors=10),
               GaussianNB(),
               MultinomialNB()]

# %%
#Function that will test the classifiers
def test_classifiers(train_data, train_classes, test_data, test_classes, classifiers):
    results = {} #Save the results in a dictionary
    
    #Loop through the different classifiers in the list
    for clf in classifiers:
        name = clf.__class__.__name__ #Grab the name of the classifier
        
        print("Now training {}...".format(name)) #Lets us know what classifier we are on
        
        start_time = time.time() #Start keeping track of time
        clf.fit(train_data, train_classes) #Fit the training data to the classifier
        predict = clf.predict(test_data) #Make predictions on test data
        
        #METRICS - Compare test data predictions with actual values
        f1 = round(f1_score(y_true=test_classes, y_pred=predict, pos_label=1), 3)
        bal_acc = round(balanced_accuracy_score(test_classes, predict), 3)
        recall = round(recall_score(test_classes, predict, pos_label=1), 3)
        #roc_auc = round(roc_auc_score(test_classes,clf.predict_proba(test_data)), 3)
        
        stop_time = time.time() #Stop keeping track of time
        runtime = round(stop_time - start_time, 3) #Calculate run time
        
        print("{} trained in {} with \n  F1: {} \n  Balanced Accuracy: {} \n  Recall: {}".format(name,runtime,f1,bal_acc,recall))
        
        results[name] = (f1, bal_acc, recall, runtime)
        
    return results

# %% [markdown]
# ### Tomek Modeling Data

# %%
#classifier_results_tomek = test_classifiers(Xtrain_tomek, ytrain_tomek, Xdev_tomek, ydev_tomek, classifiers)
# Out:
# Now training XGBClassifier...
# [13:40:00] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# XGBClassifier trained in 941.981 with
#   F1: 0.888
#   Balanced Accuracy: 0.913
#   Recall: 0.825
# Now training LGBMClassifier...
# LGBMClassifier trained in 45.119 with
#   F1: 0.121
#   Balanced Accuracy: 0.963
#   Recall: 0.943
# Now training RandomForestClassifier...
# RandomForestClassifier trained in 1551.686 with
#   F1: 0.864
#   Balanced Accuracy: 0.89
#   Recall: 0.78
# Now training ExtraTreesClassifier...
# ExtraTreesClassifier trained in 386.59 with
#   F1: 0.876
#   Balanced Accuracy: 0.897
#   Recall: 0.793
# Now training GradientBoostingClassifier...
# GradientBoostingClassifier trained in 1663.791 with
#   F1: 0.528
#   Balanced Accuracy: 0.71
#   Recall: 0.421
# Now training DecisionTreeClassifier...
# DecisionTreeClassifier trained in 56.936 with
#   F1: 0.904
#   Balanced Accuracy: 0.95
#   Recall: 0.9
# Now training ExtraTreeClassifier...
# ExtraTreeClassifier trained in 9.967 with
#   F1: 0.797
#   Balanced Accuracy: 0.895
#   Recall: 0.791
# Now training LogisticRegression...
# LogisticRegression trained in 45.018 with
#   F1: 0.713
#   Balanced Accuracy: 0.79
#   Recall: 0.581
# Now training RidgeClassifier...
# RidgeClassifier trained in 12.387 with
#   F1: 0.0
#   Balanced Accuracy: 0.5
#   Recall: 0.0
# Now training SGDClassifier...
# SGDClassifier trained in 16.862 with
#   F1: 0.63
#   Balanced Accuracy: 0.802
#   Recall: 0.605
# Now training KNeighborsClassifier...
# KNeighborsClassifier trained in 298.414 with
#   F1: 0.842
#   Balanced Accuracy: 0.872
#   Recall: 0.744
# Now training GaussianNB...
# GaussianNB trained in 10.012 with
#   F1: 0.005
#   Balanced Accuracy: 0.719
#   Recall: 0.998
# Now training MultinomialNB...
# MultinomialNB trained in 7.588 with
#   F1: 0.032
#   Balanced Accuracy: 0.87
#   Recall: 0.803

# %%
#5/18/23
#Save the dictionary so we do not have to re-run above code again
pickle_list = [classifier_results_tomek]
f = open('classifier_results_tomek.pckl','wb')
pickle.dump(pickle_list,f)
f.close()

# %% [markdown]
# ### Tomek + RUS Modeling Data

# %%
#classifier_results_rus = test_classifiers(Xtrain_rus, ytrain_rus, Xdev_rus, ydev_rus, classifiers)
# Out:
# Now training XGBClassifier...
# XGBClassifier trained in 0.939 with
#   F1: 0.994
#   Balanced Accuracy: 0.994
#   Recall: 0.997
# Now training LGBMClassifier...
# LGBMClassifier trained in 0.425 with
#   F1: 0.994
#   Balanced Accuracy: 0.994
#   Recall: 0.998
# Now training RandomForestClassifier...
# RandomForestClassifier trained in 0.881 with
#   F1: 0.992
#   Balanced Accuracy: 0.992
#   Recall: 0.997
# Now training ExtraTreesClassifier...
# ExtraTreesClassifier trained in 0.599 with
#   F1: 0.99
#   Balanced Accuracy: 0.99
#   Recall: 0.993
# Now training GradientBoostingClassifier...
# GradientBoostingClassifier trained in 1.657 with
#   F1: 0.988
#   Balanced Accuracy: 0.988
#   Recall: 0.995
# Now training DecisionTreeClassifier...
# DecisionTreeClassifier trained in 0.058 with
#   F1: 0.991
#   Balanced Accuracy: 0.991
#   Recall: 0.993
# Now training ExtraTreeClassifier...
# ExtraTreeClassifier trained in 0.026 with
#   F1: 0.971
#   Balanced Accuracy: 0.971
#   Recall: 0.97
# Now training LogisticRegression...
# LogisticRegression trained in 0.136 with
#   F1: 0.967
#   Balanced Accuracy: 0.967
#   Recall: 0.977
# Now training RidgeClassifier...
# RidgeClassifier trained in 0.045 with
#   F1: 0.953
#   Balanced Accuracy: 0.951
#   Recall: 0.975
# Now training SGDClassifier...
# SGDClassifier trained in 0.125 with
#   F1: 0.961
#   Balanced Accuracy: 0.96
#   Recall: 0.963
# Now training KNeighborsClassifier...
# KNeighborsClassifier trained in 0.317 with
#   F1: 0.982
#   Balanced Accuracy: 0.981
#   Recall: 0.991
# Now training GaussianNB...
# GaussianNB trained in 0.022 with
#   F1: 0.772
#   Balanced Accuracy: 0.704
#   Recall: 0.998
# Now training MultinomialNB...
# MultinomialNB trained in 0.022 with
#   F1: 0.861
#   Balanced Accuracy: 0.863
#   Recall: 0.849

# %%
#5/18/23
#Save the dictionary so we do not have to re-run above code again
pickle_list = [classifier_results_rus]
f = open('classifier_results_rus.pckl','wb')
pickle.dump(pickle_list,f)
f.close()

# %% [markdown]
# ## HYPERPARAMETER TUNING

# %%
def get_tomek_data():
    f = open('tomek_data.pckl','rb')
    data = pickle.load(f)
    f.close()
    return data

def get_rus_data():
    f = open('rus_data.pckl','rb')
    data = pickle.load(f)
    f.close()
    return data

# %%
def optimize_objective(trial,datatype):
    
    if datatype == 'tomek':
        #Read in the data needed for each experiment
        data = get_tomek_data() #[Xtrain_tomek, Xdev_tomek, ytrain_tomek, ydev_tomek]
        X_train = data[0]
        X_dev = data[1]
        y_train = data[2]
        y_dev = data[3]
    
        #Use Optuna to find the best algorithm to use
        algorithm = trial.suggest_categorical('algorithm', ['XGB', 'LGBM', 'DT', 'GNB'])
    
    else:
        #Read in the data needed for each experiment
        data = get_rus_data() #[Xtrain_rus, Xdev_rus, ytrain_rus, ydev_rus]
        X_train = data[0]
        X_dev = data[1]
        y_train = data[2]
        y_dev = data[3]
    
        #Use Optuna to find the best algorithm to use
        algorithm = trial.suggest_categorical('algorithm', ['XGB', 'LGBM', 'GNB', 'RFC', 'GBC'])
    
    
    
    # XGBoost Classifier
    if algorithm == 'XGB':
        #Have Optuna suggest values for the following hyperparameters
        xgb_booster = trial.suggest_categorical('xgb_booster', ['gbtree','dart'])
        xgb_eta_exp = trial.suggest_int('xgb_eta_exp',-3,-1) #!!!
        xgb_eta_base = trial.suggest_float('xgb_eta_base',1.0,9.99) #!!!
        xgb_eta = xgb_eta_base*(10**xgb_eta_exp) 
        mcw_exp = trial.suggest_int('mcw_exp',-2,2) #!!!
        mcw_base = trial.suggest_float('mcw_base',1.0,9.99) #!!!
        xgb_mcw = mcw_base*(10**mcw_exp) 
        xgb_maxdepth = trial.suggest_int('xgb_maxdepth', 3, 30)
        xgb_gamma = trial.suggest_float('xgb_gamma', 0.0, 10.0)
        xgb_subsample = trial.suggest_float('xgb_subsample', 0.1, 1.0)
        xgb_lambda = trial.suggest_float('xgb_lambda', 1.0, 20.0)
        xgb_alpha = trial.suggest_float('xgb_alpha', 0.0, 10.0)
        
        #Create the model
        model = XGBClassifier(booster=xgb_booster, eta=xgb_eta, min_child_weight=xgb_mcw,
                             max_depth=xgb_maxdepth, gamma=xgb_gamma, subsample=xgb_subsample,
                             reg_lambda=xgb_lambda, reg_alpha=xgb_alpha, random_state=10)
    
    # LGBM Classifier
    elif algorithm == 'LGBM':
        #Have Optuna suggest values for the following hyperparameters
        lgbm_boosting = trial.suggest_categorical('lgbm_booster', ['gbdt','dart','goss'])
        lgbm_num_exp = trial.suggest_int('lgbm_num_exp',1,2) #!!!
        lgbm_num_base = trial.suggest_float('lgbm_num_base',1.0,9.99) #!!!
        lgbm_num = round(lgbm_num_base*(10**lgbm_num_exp))
        lgbm_lr_exp = trial.suggest_int('lgbm_lr_exp',-3,-1) #!!!
        lgbm_lr_base = trial.suggest_float('lgbm_lr_base',1.0,9.99) #!!!
        lgbm_learningrate = lgbm_lr_base*(10**lgbm_lr_exp)
        lgbm_maxdepth = trial.suggest_int('lgbm_maxdepth', 3, 30)
        lgbm_nl_exp = trial.suggest_int('lgbm_nl_exp',1,2) #!!!
        lgbm_nl_base = trial.suggest_float('lgbm_nl_base',1.0,9.99) #!!!
        lgbm_numleaves = round(lgbm_nl_base*(10**lgbm_nl_exp))
        lgbm_mc_exp = trial.suggest_int('lgbm_mc_exp',1,3) #!!!
        lgbm_mc_base = trial.suggest_float('lgbm_mc_base',1.0,9.99) #!!!
        lgbm_minchild = round(lgbm_mc_base*(10**lgbm_mc_exp))
        lgbm_subsample = trial.suggest_float('lgbm_subsample', 0.1, 1.0)
        lgbm_lambda = trial.suggest_float('lgbm_lambda', 1.0, 20.0)
        lgbm_alpha_exp = trial.suggest_int('lgbm_alpha_exp',-1,1) #!!!
        lgbm_alpha_base = trial.suggest_float('lgbm_alpha_base',1.0,9.99) #!!!
        lgbm_alpha = lgbm_alpha_base*(10**lgbm_alpha_exp)
        
        #Create the model
        model = LGBMClassifier(boosting_type=lgbm_boosting, num_iterations=lgbm_num,
                              learning_rate=lgbm_learningrate, max_depth=lgbm_maxdepth,
                              num_leaves=lgbm_numleaves, min_child_samples=lgbm_minchild, 
                              subsample=lgbm_subsample,reg_lambda=lgbm_lambda, reg_alpha=lgbm_alpha, 
                              random_state=10)
        
    # Decision Tree Classifier
    elif algorithm == 'DT':
        #Have Optuna suggest values for the following hyperparameters
        dt_splitter = trial.suggest_categorical('dt_splitter', ['best','random'])
        dt_maxdepth = trial.suggest_int('dt_maxdepth', 3, 30)
        dt_ml_exp = trial.suggest_int('dt_ml_exp',1,3) #!!!
        dt_ml_base = trial.suggest_int('dt_ml_base',1,9) #!!!
        dt_minleaf = round(dt_ml_base*(10**dt_ml_exp))
        
        #Create the model
        model = DecisionTreeClassifier(splitter=dt_splitter, max_depth=dt_maxdepth,
                                      min_samples_leaf=dt_minleaf, random_state=10)
    
    # Gaussian Naive Bayes
    elif algorithm == 'GNB':
        #Have Optuna suggest a value for var_smoothing
        gnb_exp = trial.suggest_int('gnb_exp',6,10) #!!!
        gnb_base = trial.suggest_float('gnb_base',1.0, 9.99) #!!!
        gnb_varsmoothing = gnb_base * (10**(-gnb_exp))
        
        #Create the model
        model = GaussianNB(var_smoothing=gnb_varsmoothing)
        
    
    # Random Forest Classifier
    elif algorithm == 'RFC':
        #Have Optuna suggest values for the following hyperparameters
        rfc_num_exp = trial.suggest_int('rfc_num_exp',1,3) #!!!
        rfc_num_base = trial.suggest_float('rfc_num_base',1.0,9.99) #!!!
        rfc_num = round(rfc_num_base*(10**rfc_num_exp))
        rfc_maxdepth = trial.suggest_int('rfc_maxdepth', 3, 30)
        rfc_ml_exp = trial.suggest_int('rfc_ml_exp',1,3) #!!!
        rfc_ml_base = trial.suggest_float('rfc_ml_base',1.0,9.99) #!!!
        rfc_minleaf = round(rfc_ml_base*(10**rfc_ml_exp))
        rfc_bootstrap = trial.suggest_categorical('rfc_bootstrap',[True, False])
        
        #Create the model
        if rfc_bootstrap == False:
            model = RandomForestClassifier(n_estimators = rfc_num, max_depth=rfc_maxdepth,
                                          min_samples_leaf=rfc_minleaf, bootstrap=rfc_bootstrap,
                                          random_state=10)
        else:
            rfc_maxsamples = trial.suggest_float('rfc_maxsamples',0.1,0.99)
            model = RandomForestClassifier(n_estimators = rfc_num, max_depth=rfc_maxdepth,
                                          min_samples_leaf=rfc_minleaf, bootstrap=rfc_bootstrap,
                                          max_samples=rfc_maxsamples,random_state=10)
    
    # Gradient Boosting Classifier
    else:
        #Have Optuna suggest values for the following hyperparameters
        gbc_learn_exp = trial.suggest_int('gbc_learn_exp',-3,-1) #!!!
        gbc_learn_base = trial.suggest_float('gbc_learn_base',1.0,9.99) #!!!
        gbc_learning = gbc_learn_base*(10**gbc_learn_exp)
        gbc_num_exp = trial.suggest_int('gbc_num_exp',1,3) #!!!
        gbc_num_base = trial.suggest_float('gbc_num_base',1.0,9.99) #!!!
        gbc_num = round(gbc_num_base*(10**gbc_num_exp))
        gbc_subsample = trial.suggest_float('gbc_subsample', 0.1, 1.0)
        gbc_ml_exp = trial.suggest_int('gbc_ml_exp',1,3) #!!!
        gbc_ml_base = trial.suggest_float('gbc_ml_base',1.0,9.99) #!!!
        gbc_minleaf = round(gbc_ml_base*(10**gbc_ml_exp))
        gbc_maxdepth = trial.suggest_int('gbc_maxdepth', 3, 30)
        
        #Create the model
        model = GradientBoostingClassifier(learning_rate=gbc_learning, n_estimators=gbc_num,
                                          subsample=gbc_subsample,min_samples_leaf=gbc_minleaf, 
                                          max_depth=gbc_maxdepth,random_state=10)
    
    
    
    #Fit and score model
    model.fit(X_train, y_train)
    score_recall = recall_score(y_true=y_dev, y_pred=model.predict(X_dev), pos_label=1)
    
    #Return Score
    return score_recall

# %% [markdown]
# ### TOMEK DATA

# %% [markdown]
# In the artemis video, we see that he creates a function "get_data". We do not need to create a function like this here because the data is already ready to go (Xtrain_tomek, Xdev_tomek, ytrain_tomek, ydev_tomek). Ideally we would want to create the function and call it in our objective function (optimize_tomek) because we don't want to rely on the fact that we have the correct variables in the global environment everytime we call the function. So we will go ahead and create the get_tomek_data() function.

# %% [markdown]
# <div class="alert alert-block alert-success">
# GOOD TO RUN!!!!

# %%
# We want to maximize the score, i.e., recall
study1 = optuna.create_study(direction="maximize")
# Run Optuna a maximum of 100 times to find the best set of params for the best algo
study1.optimize(lambda trial: optimize_objective(trial, datatype='tomek'), n_trials=100)
# Out:
# [I 2023-06-05 13:50:26,643] A new study created in memory with name: no-name-2cd8e488-fc72-4ac3-b1d8-d2f9ff03cfcc
# [I 2023-06-05 13:50:42,017] Trial 0 finished with value: 0.6371463714637147 and parameters: {'algorithm': 'DT', 'dt_splitter': 'random', 'dt_maxdepth': 29, 'dt_ml_exp': 2, 'dt_ml_base': 4}. Best is trial 0 with value: 0.6371463714637147.
# [I 2023-06-05 14:39:13,770] Trial 1 finished with value: 0.7183271832718328 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'dart', 'lgbm_num_exp': 2, 'lgbm_num_base': 7.542094049019105, 'lgbm_lr_exp': -2, 'lgbm_lr_base': 4.004821571457194, 'lgbm_maxdepth': 8, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 7.094678004749073, 'lgbm_mc_exp': 3, 'lgbm_mc_base': 4.836711734961391, 'lgbm_subsample': 0.7217060240401513, 'lgbm_lambda': 10.641240484437608, 'lgbm_alpha_exp': 0, 'lgbm_alpha_base': 6.9892167179595}. Best is trial 1 with value: 0.7183271832718328.
# [I 2023-06-05 14:39:25,044] Trial 2 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.125860889745052}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:41:19,174] Trial 3 finished with value: 0.0 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'dart', 'lgbm_num_exp': 1, 'lgbm_num_base': 9.942191907634216, 'lgbm_lr_exp': -3, 'lgbm_lr_base': 1.703828868685475, 'lgbm_maxdepth': 26, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 2.6014956411809624, 'lgbm_mc_exp': 3, 'lgbm_mc_base': 2.6346095863872185, 'lgbm_subsample': 0.15324973081336365, 'lgbm_lambda': 13.013987855583334, 'lgbm_alpha_exp': 0, 'lgbm_alpha_base': 1.813754754020037}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:42:14,014] Trial 4 finished with value: 0.7798277982779828 and parameters: {'algorithm': 'DT', 'dt_splitter': 'best', 'dt_maxdepth': 28, 'dt_ml_exp': 1, 'dt_ml_base': 7}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:42:23,362] Trial 5 finished with value: 0.7945879458794588 and parameters: {'algorithm': 'GNB', 'gnb_exp': 6, 'gnb_base': 4.118477545684318}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:42:36,066] Trial 6 finished with value: 0.7244772447724477 and parameters: {'algorithm': 'DT', 'dt_splitter': 'random', 'dt_maxdepth': 19, 'dt_ml_exp': 1, 'dt_ml_base': 7}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:42:44,238] Trial 7 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 3.510608280551681}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:42:54,271] Trial 8 finished with value: 0.0 and parameters: {'algorithm': 'DT', 'dt_splitter': 'random', 'dt_maxdepth': 17, 'dt_ml_exp': 3, 'dt_ml_base': 4}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:43:27,667] Trial 9 finished with value: 0.0 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'dart', 'lgbm_num_exp': 1, 'lgbm_num_base': 4.609580405704204, 'lgbm_lr_exp': -3, 'lgbm_lr_base': 2.3832879896527306, 'lgbm_maxdepth': 16, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 8.445976293280667, 'lgbm_mc_exp': 2, 'lgbm_mc_base': 6.37991180551784, 'lgbm_subsample': 0.9651851896101529, 'lgbm_lambda': 6.336342365516925, 'lgbm_alpha_exp': 0, 'lgbm_alpha_base': 3.1335245598775137}. Best is trial 2 with value: 0.997539975399754.
# [14:43:35] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 14:54:54,847] Trial 10 finished with value: 0.6531365313653137 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -2, 'xgb_eta_base': 2.6821035303480447, 'mcw_exp': 0, 'mcw_base': 9.532541596432102, 'xgb_maxdepth': 8, 'xgb_gamma': 7.4556919884885975, 'xgb_subsample': 0.7208122725280365, 'xgb_lambda': 16.573744894094283, 'xgb_alpha': 6.638199806922174}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:55:04,411] Trial 11 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.211997476671375}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:55:13,086] Trial 12 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.2457073663305094}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:55:21,116] Trial 13 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.976370205210701}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 14:55:29,187] Trial 14 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 6.43425173729521}. Best is trial 2 with value: 0.997539975399754.
# [14:55:37] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 15:06:23,476] Trial 15 finished with value: 0.3899138991389914 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -3, 'xgb_eta_base': 9.878927935837867, 'mcw_exp': -2, 'mcw_base': 1.3144780211368117, 'xgb_maxdepth': 29, 'xgb_gamma': 0.4606855689040259, 'xgb_subsample': 0.1088405680655502, 'xgb_lambda': 2.81342672414846, 'xgb_alpha': 0.6234514187387852}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:06:33,457] Trial 16 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 5.9716820536874}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:06:42,325] Trial 17 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 3.5784905414246295}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:06:51,206] Trial 18 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.938155000531474}. Best is trial 2 with value: 0.997539975399754.
# [15:06:59] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 15:15:21,986] Trial 19 finished with value: 0.6568265682656826 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -1, 'xgb_eta_base': 1.9277918597685022, 'mcw_exp': 2, 'mcw_base': 5.633634906357093, 'xgb_maxdepth': 24, 'xgb_gamma': 9.510700396781747, 'xgb_subsample': 0.9622403712608569, 'xgb_lambda': 19.476224141736473, 'xgb_alpha': 9.927681824615364}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:15:32,547] Trial 20 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 7.798021647400549}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:15:41,962] Trial 21 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.845575247382122}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:15:52,514] Trial 22 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.490379195266636}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:16:02,579] Trial 23 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.66826388432025}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:16:11,678] Trial 24 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 7.180672418472099}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:16:20,544] Trial 25 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.17078736947516}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:16:30,187] Trial 26 finished with value: 0.972939729397294 and parameters: {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 7.081807845681563}. Best is trial 2 with value: 0.997539975399754.
# [15:16:41] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 15:24:41,590] Trial 27 finished with value: 0.32718327183271834 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -3, 'xgb_eta_base': 6.8287619747004165, 'mcw_exp': 2, 'mcw_base': 1.1784670290323866, 'xgb_maxdepth': 3, 'xgb_gamma': 3.3561818553964518, 'xgb_subsample': 0.3627539777283519, 'xgb_lambda': 7.7459196803626496, 'xgb_alpha': 0.509886763736846}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:26:21,970] Trial 28 finished with value: 0.8314883148831488 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'goss', 'lgbm_num_exp': 2, 'lgbm_num_base': 1.8067186006975513, 'lgbm_lr_exp': -1, 'lgbm_lr_base': 9.577837441957456, 'lgbm_maxdepth': 30, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 1.034396140941686, 'lgbm_mc_exp': 1, 'lgbm_mc_base': 9.919736401592171, 'lgbm_subsample': 0.3077266692509484, 'lgbm_lambda': 19.892511620465694, 'lgbm_alpha_exp': -1, 'lgbm_alpha_base': 9.927645510947794}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:26:49,949] Trial 29 finished with value: 0.15375153751537515 and parameters: {'algorithm': 'DT', 'dt_splitter': 'best', 'dt_maxdepth': 3, 'dt_ml_exp': 3, 'dt_ml_base': 1}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:26:59,216] Trial 30 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 5.07060767071901}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:27:07,370] Trial 31 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.6459730959438224}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:27:15,355] Trial 32 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.0592944991727078}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:27:23,505] Trial 33 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 2.528330485031052}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:27:36,608] Trial 34 finished with value: 0.7380073800738007 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'gbdt', 'lgbm_num_exp': 1, 'lgbm_num_base': 1.1285864355853272, 'lgbm_lr_exp': -1, 'lgbm_lr_base': 6.626204516287775, 'lgbm_maxdepth': 6, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 9.647918581594158, 'lgbm_mc_exp': 1, 'lgbm_mc_base': 1.6768631346088343, 'lgbm_subsample': 0.5119645225526522, 'lgbm_lambda': 2.1699955687844223, 'lgbm_alpha_exp': 1, 'lgbm_alpha_base': 4.952023082755624}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:27:44,599] Trial 35 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.6297448906114167}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:27:52,944] Trial 36 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 4.995713233196579}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:28:20,656] Trial 37 finished with value: 0.15375153751537515 and parameters: {'algorithm': 'DT', 'dt_splitter': 'best', 'dt_maxdepth': 3, 'dt_ml_exp': 2, 'dt_ml_base': 9}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:30:08,776] Trial 38 finished with value: 0.7712177121771218 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'gbdt', 'lgbm_num_exp': 2, 'lgbm_num_base': 4.742067883011248, 'lgbm_lr_exp': -2, 'lgbm_lr_base': 6.2773988471403595, 'lgbm_maxdepth': 19, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 4.744027389155035, 'lgbm_mc_exp': 2, 'lgbm_mc_base': 9.922461300401107, 'lgbm_subsample': 0.9357535499172893, 'lgbm_lambda': 2.4367976332667762, 'lgbm_alpha_exp': 1, 'lgbm_alpha_base': 1.206141580667711}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:30:19,343] Trial 39 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 4.220663135011701}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:31:14,198] Trial 40 finished with value: 0.7613776137761378 and parameters: {'algorithm': 'DT', 'dt_splitter': 'best', 'dt_maxdepth': 13, 'dt_ml_exp': 1, 'dt_ml_base': 1}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:31:22,637] Trial 41 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.598442108333739}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:31:31,312] Trial 42 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.747126105275814}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:31:39,521] Trial 43 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 8.996899048440051}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:31:47,501] Trial 44 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.780507255632617}. Best is trial 2 with value: 0.997539975399754.
# [15:31:54] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 15:51:25,412] Trial 45 finished with value: 0.7724477244772447 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -1, 'xgb_eta_base': 5.328503171265846, 'mcw_exp': -2, 'mcw_base': 9.559735002064023, 'xgb_maxdepth': 16, 'xgb_gamma': 5.0532742524236545, 'xgb_subsample': 0.5264298876965094, 'xgb_lambda': 12.408720886599083, 'xgb_alpha': 4.161596051254687}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:51:35,868] Trial 46 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.89887086750308}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:51:44,873] Trial 47 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.932446377801945}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:52:27,443] Trial 48 finished with value: 0.6088560885608856 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'goss', 'lgbm_num_exp': 1, 'lgbm_num_base': 9.752228220200672, 'lgbm_lr_exp': -3, 'lgbm_lr_base': 9.908651916436252, 'lgbm_maxdepth': 14, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 5.697418150727799, 'lgbm_mc_exp': 1, 'lgbm_mc_base': 7.068777923689126, 'lgbm_subsample': 0.45331341595299274, 'lgbm_lambda': 19.996133849686494, 'lgbm_alpha_exp': -1, 'lgbm_alpha_base': 9.892121389671036}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 15:52:36,114] Trial 49 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.404909129461569}. Best is trial 2 with value: 0.997539975399754.
# [15:52:44] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 16:07:22,441] Trial 50 finished with value: 0.6777367773677737 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -2, 'xgb_eta_base': 1.4063710956166764, 'mcw_exp': 0, 'mcw_base': 5.049664136139949, 'xgb_maxdepth': 16, 'xgb_gamma': 0.10818942197209402, 'xgb_subsample': 0.9855119597627744, 'xgb_lambda': 1.4060536198661424, 'xgb_alpha': 9.881565854753141}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:07:33,068] Trial 51 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 3.596609961288585}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:07:41,589] Trial 52 finished with value: 0.8142681426814268 and parameters: {'algorithm': 'GNB', 'gnb_exp': 6, 'gnb_base': 3.5061375450364025}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:07:49,628] Trial 53 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 4.286621634567281}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:07:57,754] Trial 54 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 5.514578390041905}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:08:06,162] Trial 55 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.730092807279913}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:08:14,341] Trial 56 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 6.376408077592706}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:08:23,956] Trial 57 finished with value: 0.0 and parameters: {'algorithm': 'DT', 'dt_splitter': 'random', 'dt_maxdepth': 10, 'dt_ml_exp': 3, 'dt_ml_base': 9}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:08:32,139] Trial 58 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.335513496117267}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:08:40,157] Trial 59 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.052193108874128}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:08:48,464] Trial 60 finished with value: 0.9630996309963099 and parameters: {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 9.24234123168141}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:08:56,439] Trial 61 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.00346510492583}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:09:05,075] Trial 62 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.602650179153255}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:09:13,451] Trial 63 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.361486901162882}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:09:22,313] Trial 64 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.592227703218046}. Best is trial 2 with value: 0.997539975399754.
# [16:09:29] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 16:15:43,822] Trial 65 finished with value: 0.6851168511685117 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -1, 'xgb_eta_base': 9.863565858783126, 'mcw_exp': 1, 'mcw_base': 6.7342940208041755, 'xgb_maxdepth': 23, 'xgb_gamma': 9.63719476028373, 'xgb_subsample': 0.13673371523407413, 'xgb_lambda': 9.521541934295202, 'xgb_alpha': 3.892628318489626}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:15:53,041] Trial 66 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.960584027175399}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:18:51,912] Trial 67 finished with value: 0.7626076260762608 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'goss', 'lgbm_num_exp': 2, 'lgbm_num_base': 6.64530474549863, 'lgbm_lr_exp': -1, 'lgbm_lr_base': 1.0500509335816997, 'lgbm_maxdepth': 3, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 4.075258822060226, 'lgbm_mc_exp': 3, 'lgbm_mc_base': 3.477559475462096, 'lgbm_subsample': 0.10204912996206938, 'lgbm_lambda': 13.63520628022, 'lgbm_alpha_exp': -1, 'lgbm_alpha_base': 6.68318403982561}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:19:01,027] Trial 68 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.031404860176306}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:19:10,539] Trial 69 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 6.921165210611006}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:20:01,732] Trial 70 finished with value: 0.7392373923739237 and parameters: {'algorithm': 'DT', 'dt_splitter': 'best', 'dt_maxdepth': 23, 'dt_ml_exp': 2, 'dt_ml_base': 3}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:20:10,645] Trial 71 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.22765259452856}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:20:18,523] Trial 72 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.684277578210162}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:20:27,018] Trial 73 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.0039452471638048}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:20:35,263] Trial 74 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.6057902847414045}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:20:44,236] Trial 75 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.2753900449495212}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:20:52,437] Trial 76 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.428689922209422}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:21:00,466] Trial 77 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 1.6987860816686156}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:21:15,321] Trial 78 finished with value: 0.7269372693726938 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'gbdt', 'lgbm_num_exp': 1, 'lgbm_num_base': 2.797314195683815, 'lgbm_lr_exp': -2, 'lgbm_lr_base': 4.00371264659992, 'lgbm_maxdepth': 22, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 6.9086253809594105, 'lgbm_mc_exp': 2, 'lgbm_mc_base': 1.0821225112205397, 'lgbm_subsample': 0.7597290017541899, 'lgbm_lambda': 7.083139690435756, 'lgbm_alpha_exp': 1, 'lgbm_alpha_base': 3.844608909221174}. Best is trial 2 with value: 0.997539975399754.
# [16:21:23] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 16:32:02,357] Trial 79 finished with value: 0.2890528905289053 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -3, 'xgb_eta_base': 4.705179425271604, 'mcw_exp': -1, 'mcw_base': 3.3573649433558272, 'xgb_maxdepth': 10, 'xgb_gamma': 4.4796429235296, 'xgb_subsample': 0.7242184814695571, 'xgb_lambda': 14.142621268260292, 'xgb_alpha': 6.947420408242256}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:32:12,638] Trial 80 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 8.898654838588516}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:32:22,537] Trial 81 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.549147484859034}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:32:31,983] Trial 82 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.940165916584485}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:32:40,633] Trial 83 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.622473403068545}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:32:49,047] Trial 84 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.953587637135225}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:32:58,449] Trial 85 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.534589427950436}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:33:08,453] Trial 86 finished with value: 0.0 and parameters: {'algorithm': 'DT', 'dt_splitter': 'random', 'dt_maxdepth': 9, 'dt_ml_exp': 3, 'dt_ml_base': 6}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:33:17,776] Trial 87 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.226975855510682}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:33:26,006] Trial 88 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.664392784837505}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:33:34,006] Trial 89 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 4.7767466911116045}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:33:42,610] Trial 90 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 5.774457651766678}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:33:50,705] Trial 91 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 3.527710994866858}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:33:59,859] Trial 92 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.72344214780962}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:34:08,704] Trial 93 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.13854517495575}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:34:17,211] Trial 94 finished with value: 0.996309963099631 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 8.286709805494105}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:34:26,290] Trial 95 finished with value: 0.982779827798278 and parameters: {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 5.1569308196215795}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:35:11,022] Trial 96 finished with value: 0.7158671586715867 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'gbdt', 'lgbm_num_exp': 2, 'lgbm_num_base': 3.5585601768207304, 'lgbm_lr_exp': -1, 'lgbm_lr_base': 7.868988911784294, 'lgbm_maxdepth': 12, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 9.4914166558088, 'lgbm_mc_exp': 1, 'lgbm_mc_base': 4.417254975055974, 'lgbm_subsample': 0.6260760114620976, 'lgbm_lambda': 15.260596163016771, 'lgbm_alpha_exp': 1, 'lgbm_alpha_base': 7.733814477312743}. Best is trial 2 with value: 0.997539975399754.
# [16:35:21] WARNING: xgboost/src/gbm/gbtree.cc:139: Tree method is automatically selected to be 'approx' for faster speed. To use old behavior (exact greedy algorithm on single machine), set tree_method to 'exact'.
# [I 2023-06-05 16:47:19,643] Trial 97 finished with value: 0.6728167281672817 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -2, 'xgb_eta_base': 7.628990123268456, 'mcw_exp': 1, 'mcw_base': 8.600865811984923, 'xgb_maxdepth': 30, 'xgb_gamma': 7.09328508261839, 'xgb_subsample': 0.326872365377617, 'xgb_lambda': 6.150834492882952, 'xgb_alpha': 2.7310207131912816}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:47:30,977] Trial 98 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.921897036574144}. Best is trial 2 with value: 0.997539975399754.
# [I 2023-06-05 16:47:40,623] Trial 99 finished with value: 0.997539975399754 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.514885322573242}. Best is trial 2 with value: 0.997539975399754.

# %%
def get_optuna_trials(study, top_n):
    all_trials = study.get_trials() #Grab all trials from study
    res_trials = {} #instantiate dictionary for trials that will contain information we want to look at
    for _t in all_trials:
        res_trials[_t.number] = (_t.value, _t.params) #Will look at recall, and parameters
        
    #Sort the trials based on the items listed in the dictionary
    f_trials = sorted(res_trials.items(), key=lambda x:x[1][0], reverse=True)[:top_n]
    #.items() shows the key-value pairs in a dictionary. This is what we are sorting.
    #key defines how we sort the list, and in this case we are sorting by the recall value
    #We only want to grab the top_n trials 
    
    #return the top_n sorted trials
    return f_trials

# %%
f_trials_tomek = get_optuna_trials(study1, 100)
f_trials_tomek
# Out:
# [(2,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.125860889745052})),
#  (7,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 3.510608280551681})),
#  (11,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.211997476671375})),
#  (12,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.2457073663305094})),
#  (13,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.976370205210701})),
#  (17,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 3.5784905414246295})),
#  (18,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.938155000531474})),
#  (20,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 7.798021647400549})),
#  (21,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.845575247382122})),
#  (22,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.490379195266636})),
#  (23,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.66826388432025})),
#  (24,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 7.180672418472099})),
#  (25,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.17078736947516})),
#  (30,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 5.07060767071901})),
#  (31,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.6459730959438224})),
#  (32,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.0592944991727078})),
#  (33,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 2.528330485031052})),
#  (35,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.6297448906114167})),
#  (39,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 4.220663135011701})),
#  (41,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.598442108333739})),
#  (42,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.747126105275814})),
#  (44,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.780507255632617})),
#  (46,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.89887086750308})),
#  (47,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.932446377801945})),
#  (49,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.404909129461569})),
#  (51,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 3.596609961288585})),
#  (53,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 4.286621634567281})),
#  (55,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.730092807279913})),
#  (58,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.335513496117267})),
#  (59,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.052193108874128})),
#  (61,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.00346510492583})),
#  (62,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.602650179153255})),
#  (63,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.361486901162882})),
#  (64,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.592227703218046})),
#  (66,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.960584027175399})),
#  (68,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.031404860176306})),
#  (69,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 6.921165210611006})),
#  (71,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.22765259452856})),
#  (72,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.684277578210162})),
#  (73,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 1.0039452471638048})),
#  (74,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.6057902847414045})),
#  (75,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.2753900449495212})),
#  (76,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.428689922209422})),
#  (77,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 1.6987860816686156})),
#  (81,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.549147484859034})),
#  (82,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.940165916584485})),
#  (83,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.622473403068545})),
#  (84,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.953587637135225})),
#  (85,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.534589427950436})),
#  (87,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.226975855510682})),
#  (88,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 9.664392784837505})),
#  (89,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 4.7767466911116045})),
#  (90,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 5.774457651766678})),
#  (91,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 3.527710994866858})),
#  (92,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.72344214780962})),
#  (93,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.13854517495575})),
#  (98,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 2.921897036574144})),
#  (99,
#   (0.997539975399754,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.514885322573242})),
#  (14,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 6.43425173729521})),
#  (16,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 5.9716820536874})),
#  (36,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 4.995713233196579})),
#  (43,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 8.996899048440051})),
#  (54,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 5.514578390041905})),
#  (56,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 6.376408077592706})),
#  (80,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 8.898654838588516})),
#  (94,
#   (0.996309963099631,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 8.286709805494105})),
#  (95,
#   (0.982779827798278,
#    {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 5.1569308196215795})),
#  (26,
#   (0.972939729397294,
#    {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 7.081807845681563})),
#  (60,
#   (0.9630996309963099,
#    {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 9.24234123168141})),
#  (28,
#   (0.8314883148831488,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'goss',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 1.8067186006975513,
#     'lgbm_lr_exp': -1,
#     'lgbm_lr_base': 9.577837441957456,
#     'lgbm_maxdepth': 30,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 1.034396140941686,
#     'lgbm_mc_exp': 1,
#     'lgbm_mc_base': 9.919736401592171,
#     'lgbm_subsample': 0.3077266692509484,
#     'lgbm_lambda': 19.892511620465694,
#     'lgbm_alpha_exp': -1,
#     'lgbm_alpha_base': 9.927645510947794})),
#  (52,
#   (0.8142681426814268,
#    {'algorithm': 'GNB', 'gnb_exp': 6, 'gnb_base': 3.5061375450364025})),
#  (5,
#   (0.7945879458794588,
#    {'algorithm': 'GNB', 'gnb_exp': 6, 'gnb_base': 4.118477545684318})),
#  (4,
#   (0.7798277982779828,
#    {'algorithm': 'DT',
#     'dt_splitter': 'best',
#     'dt_maxdepth': 28,
#     'dt_ml_exp': 1,
#     'dt_ml_base': 7})),
#  (45,
#   (0.7724477244772447,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -1,
#     'xgb_eta_base': 5.328503171265846,
#     'mcw_exp': -2,
#     'mcw_base': 9.559735002064023,
#     'xgb_maxdepth': 16,
#     'xgb_gamma': 5.0532742524236545,
#     'xgb_subsample': 0.5264298876965094,
#     'xgb_lambda': 12.408720886599083,
#     'xgb_alpha': 4.161596051254687})),
#  (38,
#   (0.7712177121771218,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'gbdt',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 4.742067883011248,
#     'lgbm_lr_exp': -2,
#     'lgbm_lr_base': 6.2773988471403595,
#     'lgbm_maxdepth': 19,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 4.744027389155035,
#     'lgbm_mc_exp': 2,
#     'lgbm_mc_base': 9.922461300401107,
#     'lgbm_subsample': 0.9357535499172893,
#     'lgbm_lambda': 2.4367976332667762,
#     'lgbm_alpha_exp': 1,
#     'lgbm_alpha_base': 1.206141580667711})),
#  (67,
#   (0.7626076260762608,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'goss',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 6.64530474549863,
#     'lgbm_lr_exp': -1,
#     'lgbm_lr_base': 1.0500509335816997,
#     'lgbm_maxdepth': 3,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 4.075258822060226,
#     'lgbm_mc_exp': 3,
#     'lgbm_mc_base': 3.477559475462096,
#     'lgbm_subsample': 0.10204912996206938,
#     'lgbm_lambda': 13.63520628022,
#     'lgbm_alpha_exp': -1,
#     'lgbm_alpha_base': 6.68318403982561})),
#  (40,
#   (0.7613776137761378,
#    {'algorithm': 'DT',
#     'dt_splitter': 'best',
#     'dt_maxdepth': 13,
#     'dt_ml_exp': 1,
#     'dt_ml_base': 1})),
#  (70,
#   (0.7392373923739237,
#    {'algorithm': 'DT',
#     'dt_splitter': 'best',
#     'dt_maxdepth': 23,
#     'dt_ml_exp': 2,
#     'dt_ml_base': 3})),
#  (34,
#   (0.7380073800738007,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'gbdt',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 1.1285864355853272,
#     'lgbm_lr_exp': -1,
#     'lgbm_lr_base': 6.626204516287775,
#     'lgbm_maxdepth': 6,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 9.647918581594158,
#     'lgbm_mc_exp': 1,
#     'lgbm_mc_base': 1.6768631346088343,
#     'lgbm_subsample': 0.5119645225526522,
#     'lgbm_lambda': 2.1699955687844223,
#     'lgbm_alpha_exp': 1,
#     'lgbm_alpha_base': 4.952023082755624})),
#  (78,
#   (0.7269372693726938,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'gbdt',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 2.797314195683815,
#     'lgbm_lr_exp': -2,
#     'lgbm_lr_base': 4.00371264659992,
#     'lgbm_maxdepth': 22,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 6.9086253809594105,
#     'lgbm_mc_exp': 2,
#     'lgbm_mc_base': 1.0821225112205397,
#     'lgbm_subsample': 0.7597290017541899,
#     'lgbm_lambda': 7.083139690435756,
#     'lgbm_alpha_exp': 1,
#     'lgbm_alpha_base': 3.844608909221174})),
#  (6,
#   (0.7244772447724477,
#    {'algorithm': 'DT',
#     'dt_splitter': 'random',
#     'dt_maxdepth': 19,
#     'dt_ml_exp': 1,
#     'dt_ml_base': 7})),
#  (1,
#   (0.7183271832718328,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'dart',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 7.542094049019105,
#     'lgbm_lr_exp': -2,
#     'lgbm_lr_base': 4.004821571457194,
#     'lgbm_maxdepth': 8,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 7.094678004749073,
#     'lgbm_mc_exp': 3,
#     'lgbm_mc_base': 4.836711734961391,
#     'lgbm_subsample': 0.7217060240401513,
#     'lgbm_lambda': 10.641240484437608,
#     'lgbm_alpha_exp': 0,
#     'lgbm_alpha_base': 6.9892167179595})),
#  (96,
#   (0.7158671586715867,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'gbdt',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 3.5585601768207304,
#     'lgbm_lr_exp': -1,
#     'lgbm_lr_base': 7.868988911784294,
#     'lgbm_maxdepth': 12,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 9.4914166558088,
#     'lgbm_mc_exp': 1,
#     'lgbm_mc_base': 4.417254975055974,
#     'lgbm_subsample': 0.6260760114620976,
#     'lgbm_lambda': 15.260596163016771,
#     'lgbm_alpha_exp': 1,
#     'lgbm_alpha_base': 7.733814477312743})),
#  (65,
#   (0.6851168511685117,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -1,
#     'xgb_eta_base': 9.863565858783126,
#     'mcw_exp': 1,
#     'mcw_base': 6.7342940208041755,
#     'xgb_maxdepth': 23,
#     'xgb_gamma': 9.63719476028373,
#     'xgb_subsample': 0.13673371523407413,
#     'xgb_lambda': 9.521541934295202,
#     'xgb_alpha': 3.892628318489626})),
#  (50,
#   (0.6777367773677737,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -2,
#     'xgb_eta_base': 1.4063710956166764,
#     'mcw_exp': 0,
#     'mcw_base': 5.049664136139949,
#     'xgb_maxdepth': 16,
#     'xgb_gamma': 0.10818942197209402,
#     'xgb_subsample': 0.9855119597627744,
#     'xgb_lambda': 1.4060536198661424,
#     'xgb_alpha': 9.881565854753141})),
#  (97,
#   (0.6728167281672817,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -2,
#     'xgb_eta_base': 7.628990123268456,
#     'mcw_exp': 1,
#     'mcw_base': 8.600865811984923,
#     'xgb_maxdepth': 30,
#     'xgb_gamma': 7.09328508261839,
#     'xgb_subsample': 0.326872365377617,
#     'xgb_lambda': 6.150834492882952,
#     'xgb_alpha': 2.7310207131912816})),
#  (19,
#   (0.6568265682656826,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -1,
#     'xgb_eta_base': 1.9277918597685022,
#     'mcw_exp': 2,
#     'mcw_base': 5.633634906357093,
#     'xgb_maxdepth': 24,
#     'xgb_gamma': 9.510700396781747,
#     'xgb_subsample': 0.9622403712608569,
#     'xgb_lambda': 19.476224141736473,
#     'xgb_alpha': 9.927681824615364})),
#  (10,
#   (0.6531365313653137,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -2,
#     'xgb_eta_base': 2.6821035303480447,
#     'mcw_exp': 0,
#     'mcw_base': 9.532541596432102,
#     'xgb_maxdepth': 8,
#     'xgb_gamma': 7.4556919884885975,
#     'xgb_subsample': 0.7208122725280365,
#     'xgb_lambda': 16.573744894094283,
#     'xgb_alpha': 6.638199806922174})),
#  (0,
#   (0.6371463714637147,
#    {'algorithm': 'DT',
#     'dt_splitter': 'random',
#     'dt_maxdepth': 29,
#     'dt_ml_exp': 2,
#     'dt_ml_base': 4})),
#  (48,
#   (0.6088560885608856,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'goss',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 9.752228220200672,
#     'lgbm_lr_exp': -3,
#     'lgbm_lr_base': 9.908651916436252,
#     'lgbm_maxdepth': 14,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 5.697418150727799,
#     'lgbm_mc_exp': 1,
#     'lgbm_mc_base': 7.068777923689126,
#     'lgbm_subsample': 0.45331341595299274,
#     'lgbm_lambda': 19.996133849686494,
#     'lgbm_alpha_exp': -1,
#     'lgbm_alpha_base': 9.892121389671036})),
#  (15,
#   (0.3899138991389914,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -3,
#     'xgb_eta_base': 9.878927935837867,
#     'mcw_exp': -2,
#     'mcw_base': 1.3144780211368117,
#     'xgb_maxdepth': 29,
#     'xgb_gamma': 0.4606855689040259,
#     'xgb_subsample': 0.1088405680655502,
#     'xgb_lambda': 2.81342672414846,
#     'xgb_alpha': 0.6234514187387852})),
#  (27,
#   (0.32718327183271834,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -3,
#     'xgb_eta_base': 6.8287619747004165,
#     'mcw_exp': 2,
#     'mcw_base': 1.1784670290323866,
#     'xgb_maxdepth': 3,
#     'xgb_gamma': 3.3561818553964518,
#     'xgb_subsample': 0.3627539777283519,
#     'xgb_lambda': 7.7459196803626496,
#     'xgb_alpha': 0.509886763736846})),
#  (79,
#   (0.2890528905289053,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -3,
#     'xgb_eta_base': 4.705179425271604,
#     'mcw_exp': -1,
#     'mcw_base': 3.3573649433558272,
#     'xgb_maxdepth': 10,
#     'xgb_gamma': 4.4796429235296,
#     'xgb_subsample': 0.7242184814695571,
#     'xgb_lambda': 14.142621268260292,
#     'xgb_alpha': 6.947420408242256})),
#  (29,
#   (0.15375153751537515,
#    {'algorithm': 'DT',
#     'dt_splitter': 'best',
#     'dt_maxdepth': 3,
#     'dt_ml_exp': 3,
#     'dt_ml_base': 1})),
#  (37,
#   (0.15375153751537515,
#    {'algorithm': 'DT',
#     'dt_splitter': 'best',
#     'dt_maxdepth': 3,
#     'dt_ml_exp': 2,
#     'dt_ml_base': 9})),
#  (3,
#   (0.0,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'dart',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 9.942191907634216,
#     'lgbm_lr_exp': -3,
#     'lgbm_lr_base': 1.703828868685475,
#     'lgbm_maxdepth': 26,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 2.6014956411809624,
#     'lgbm_mc_exp': 3,
#     'lgbm_mc_base': 2.6346095863872185,
#     'lgbm_subsample': 0.15324973081336365,
#     'lgbm_lambda': 13.013987855583334,
#     'lgbm_alpha_exp': 0,
#     'lgbm_alpha_base': 1.813754754020037})),
#  (8,
#   (0.0,
#    {'algorithm': 'DT',
#     'dt_splitter': 'random',
#     'dt_maxdepth': 17,
#     'dt_ml_exp': 3,
#     'dt_ml_base': 4})),
#  (9,
#   (0.0,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'dart',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 4.609580405704204,
#     'lgbm_lr_exp': -3,
#     'lgbm_lr_base': 2.3832879896527306,
#     'lgbm_maxdepth': 16,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 8.445976293280667,
#     'lgbm_mc_exp': 2,
#     'lgbm_mc_base': 6.37991180551784,
#     'lgbm_subsample': 0.9651851896101529,
#     'lgbm_lambda': 6.336342365516925,
#     'lgbm_alpha_exp': 0,
#     'lgbm_alpha_base': 3.1335245598775137})),
#  (57,
#   (0.0,
#    {'algorithm': 'DT',
#     'dt_splitter': 'random',
#     'dt_maxdepth': 10,
#     'dt_ml_exp': 3,
#     'dt_ml_base': 9})),
#  (86,
#   (0.0,
#    {'algorithm': 'DT',
#     'dt_splitter': 'random',
#     'dt_maxdepth': 9,
#     'dt_ml_exp': 3,
#     'dt_ml_base': 6}))]

# %%
#SAVE THE TOMEK TRIALS
pickle_list = [f_trials_tomek]
f = open('optuna_trials_tomek.pckl','wb')
pickle.dump(pickle_list,f)
f.close()

# %% [markdown]
# ### TOMEK + RUS DATA

# %% [markdown]
# In the artemis video, we see that he creates a function "get_data". We do not need to create a function like this here because the data is already ready to go (Xtrain_rus, Xdev_rus, ytrain_rus, ydev_rus). Ideally we would want to create the function and call it in our objective function (optimize_tomek) because we don't want to rely on the fact that we have the correct variables in the global environment everytime we call the function. So we will go ahead and create the get_tomek_data() function.

# %% [markdown]
# <div class="alert alert-block alert-success">
# GOOD TO RUN!!!!

# %%
# We want to maximize the score, i.e., recall
study2 = optuna.create_study(direction="maximize")
# Run Optuna a maximum of 100 times to find the best set of params for the best algo
study2.optimize(lambda trial: optimize_objective(trial, datatype='rus'), n_trials=100)
# Out:
# [I 2023-06-05 17:37:27,129] A new study created in memory with name: no-name-84e54d5f-9f26-4ee3-8d62-313ed10b1111
# [I 2023-06-05 17:37:36,535] Trial 0 finished with value: 0.9950779327317474 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'dart', 'lgbm_num_exp': 2, 'lgbm_num_base': 9.222876306126139, 'lgbm_lr_exp': -1, 'lgbm_lr_base': 6.31245941173835, 'lgbm_maxdepth': 22, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 9.938072043465244, 'lgbm_mc_exp': 1, 'lgbm_mc_base': 7.117969420544642, 'lgbm_subsample': 0.9115048669842948, 'lgbm_lambda': 14.104046492032666, 'lgbm_alpha_exp': 0, 'lgbm_alpha_base': 9.595196727728482}. Best is trial 0 with value: 0.9950779327317474.
# [I 2023-06-05 17:37:36,800] Trial 1 finished with value: 0.8634126333059885 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 1, 'rfc_num_base': 5.92402539190864, 'rfc_maxdepth': 15, 'rfc_ml_exp': 3, 'rfc_ml_base': 2.6294668846878064, 'rfc_bootstrap': False}. Best is trial 0 with value: 0.9950779327317474.
# [I 2023-06-05 17:37:36,934] Trial 2 finished with value: 0.9782608695652174 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'goss', 'lgbm_num_exp': 1, 'lgbm_num_base': 8.953346727520703, 'lgbm_lr_exp': -3, 'lgbm_lr_base': 1.1045774681480909, 'lgbm_maxdepth': 16, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 1.1110458863092152, 'lgbm_mc_exp': 2, 'lgbm_mc_base': 8.11876539639625, 'lgbm_subsample': 0.7408566211269251, 'lgbm_lambda': 15.848542699553548, 'lgbm_alpha_exp': 0, 'lgbm_alpha_base': 2.7083881577959437}. Best is trial 0 with value: 0.9950779327317474.
# [I 2023-06-05 17:37:37,701] Trial 3 finished with value: 0.9901558654634947 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -1, 'xgb_eta_base': 6.869577585427217, 'mcw_exp': 1, 'mcw_base': 7.030064614239413, 'xgb_maxdepth': 12, 'xgb_gamma': 7.687997946651469, 'xgb_subsample': 0.910115606681263, 'xgb_lambda': 6.052733637985947, 'xgb_alpha': 9.988233992888603}. Best is trial 0 with value: 0.9950779327317474.
# [I 2023-06-05 17:37:39,917] Trial 4 finished with value: 0.9950779327317474 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -1, 'xgb_eta_base': 5.412002301915272, 'mcw_exp': 0, 'mcw_base': 1.1839028414503587, 'xgb_maxdepth': 15, 'xgb_gamma': 6.563230215488427, 'xgb_subsample': 0.7891609078773494, 'xgb_lambda': 3.1136549805177576, 'xgb_alpha': 2.334761463110836}. Best is trial 0 with value: 0.9950779327317474.
# [I 2023-06-05 17:37:41,805] Trial 5 finished with value: 0.9967186218211649 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'goss', 'lgbm_num_exp': 2, 'lgbm_num_base': 4.7857861825870565, 'lgbm_lr_exp': -2, 'lgbm_lr_base': 4.645201530116562, 'lgbm_maxdepth': 17, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 5.409294209476331, 'lgbm_mc_exp': 1, 'lgbm_mc_base': 7.1383417313592705, 'lgbm_subsample': 0.3342514284740086, 'lgbm_lambda': 4.695611551685067, 'lgbm_alpha_exp': -1, 'lgbm_alpha_base': 4.448228031091103}. Best is trial 5 with value: 0.9967186218211649.
# [I 2023-06-05 17:37:52,244] Trial 6 finished with value: 0.9971287940935193 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -2, 'gbc_learn_base': 6.102829507416073, 'gbc_num_exp': 2, 'gbc_num_base': 4.361893013438007, 'gbc_subsample': 0.9123910040725568, 'gbc_ml_exp': 2, 'gbc_ml_base': 2.9468171812720865, 'gbc_maxdepth': 7}. Best is trial 6 with value: 0.9971287940935193.
# [I 2023-06-05 17:38:08,022] Trial 7 finished with value: 0.8338802296964725 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -1, 'gbc_learn_base': 8.693223906481471, 'gbc_num_exp': 3, 'gbc_num_base': 3.8636901404617845, 'gbc_subsample': 0.14686850908415763, 'gbc_ml_exp': 2, 'gbc_ml_base': 2.0377166804912665, 'gbc_maxdepth': 29}. Best is trial 6 with value: 0.9971287940935193.
# [I 2023-06-05 17:38:08,749] Trial 8 finished with value: 0.9741591468416735 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 2, 'rfc_num_base': 1.647484696927805, 'rfc_maxdepth': 20, 'rfc_ml_exp': 1, 'rfc_ml_base': 5.448050020639872, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.4954497338457835}. Best is trial 6 with value: 0.9971287940935193.
# [I 2023-06-05 17:38:08,781] Trial 9 finished with value: 0.9958982772764561 and parameters: {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 4.884372250771577}. Best is trial 6 with value: 0.9971287940935193.
# [I 2023-06-05 17:38:10,632] Trial 10 finished with value: 0.9934372436423298 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -3, 'gbc_learn_base': 3.379274289619472, 'gbc_num_exp': 1, 'gbc_num_base': 7.759464032322617, 'gbc_subsample': 0.9464706813274, 'gbc_ml_exp': 1, 'gbc_ml_base': 6.3770697320234895, 'gbc_maxdepth': 5}. Best is trial 6 with value: 0.9971287940935193.
# [I 2023-06-05 17:38:11,945] Trial 11 finished with value: 0.9950779327317474 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'goss', 'lgbm_num_exp': 2, 'lgbm_num_base': 2.5846136055063313, 'lgbm_lr_exp': -2, 'lgbm_lr_base': 9.418898465997744, 'lgbm_maxdepth': 3, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 5.390793703096259, 'lgbm_mc_exp': 1, 'lgbm_mc_base': 1.7872627634524672, 'lgbm_subsample': 0.23720843352242912, 'lgbm_lambda': 1.817053958480658, 'lgbm_alpha_exp': -1, 'lgbm_alpha_base': 4.253494652234595}. Best is trial 6 with value: 0.9971287940935193.
# [I 2023-06-05 17:38:13,911] Trial 12 finished with value: 0.9790812141099262 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -2, 'gbc_learn_base': 6.190772754853172, 'gbc_num_exp': 2, 'gbc_num_base': 1.2629550840656836, 'gbc_subsample': 0.9999447921014333, 'gbc_ml_exp': 3, 'gbc_ml_base': 2.3368434101055677, 'gbc_maxdepth': 5}. Best is trial 6 with value: 0.9971287940935193.
# [I 2023-06-05 17:38:13,950] Trial 13 finished with value: 0.9979491386382281 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.884648136555981}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,001] Trial 14 finished with value: 0.9979491386382281 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.780451107797834}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,043] Trial 15 finished with value: 0.9979491386382281 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.878508102046183}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,088] Trial 16 finished with value: 0.9979491386382281 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.855265500252118}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,134] Trial 17 finished with value: 0.9975389663658737 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.122436978759456}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,174] Trial 18 finished with value: 0.9975389663658737 and parameters: {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 2.4086726951456945}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,215] Trial 19 finished with value: 0.9979491386382281 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 7.676328365338093}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,266] Trial 20 finished with value: 0.9975389663658737 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.3699500279488035}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,315] Trial 21 finished with value: 0.9979491386382281 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.851760079713124}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,357] Trial 22 finished with value: 0.9979491386382281 and parameters: {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.89310147030969}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,407] Trial 23 finished with value: 0.9975389663658737 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.61786263550669}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,457] Trial 24 finished with value: 0.9938474159146842 and parameters: {'algorithm': 'GNB', 'gnb_exp': 6, 'gnb_base': 8.746155743833311}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:14,494] Trial 25 finished with value: 0.9975389663658737 and parameters: {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 6.527882068855613}. Best is trial 13 with value: 0.9979491386382281.
# [I 2023-06-05 17:38:39,670] Trial 26 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.8410100557842, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.56629896082272, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9767807421240824}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:39:00,753] Trial 27 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.51340671485012, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.752906804396432, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8924991091615007}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:39:22,670] Trial 28 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.98704820722556, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.92358683139348, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9732463247600415}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:39:44,376] Trial 29 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.94937577503255, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.980813233316885, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9611879579013174}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:40:05,824] Trial 30 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.772331582616713, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.946466380862777, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.948691509968323}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:40:27,602] Trial 31 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.850223156437691, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.941111602701715, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9588939360672871}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:40:49,314] Trial 32 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.97225240764204, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.983484624258457, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9694654502813731}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:41:10,874] Trial 33 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.808232813720277, 'rfc_maxdepth': 7, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.989534310974294, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9785731936826192}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:41:40,943] Trial 34 finished with value: 0.9356029532403609 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.510574903232618, 'rfc_maxdepth': 10, 'rfc_ml_exp': 2, 'rfc_ml_base': 8.363112535107176, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.7742683478316066}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:41:43,903] Trial 35 finished with value: 0.9360131255127153 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 2, 'rfc_num_base': 8.166167232881081, 'rfc_maxdepth': 8, 'rfc_ml_exp': 2, 'rfc_ml_base': 8.245076635550074, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.7646405679867878}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:42:01,756] Trial 36 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.234864166360003, 'rfc_maxdepth': 29, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.243881308143795, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8026075996563704}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:42:02,641] Trial 37 finished with value: 0.9273995077932732 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -3, 'xgb_eta_base': 1.5939530693409836, 'mcw_exp': -2, 'mcw_base': 9.911642937121965, 'xgb_maxdepth': 29, 'xgb_gamma': 0.08633898085273373, 'xgb_subsample': 0.10401373058306107, 'xgb_lambda': 19.912301934032435, 'xgb_alpha': 0.0015819424207190735}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:42:19,449] Trial 38 finished with value: 0.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.986446112095006, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.636784707559762, 'rfc_bootstrap': False}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:42:22,645] Trial 39 finished with value: 0.9360131255127153 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 2, 'rfc_num_base': 8.422969973942001, 'rfc_maxdepth': 8, 'rfc_ml_exp': 2, 'rfc_ml_base': 8.865426604190802, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8392322658625766}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:42:39,810] Trial 40 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.60823396455368, 'rfc_maxdepth': 7, 'rfc_ml_exp': 3, 'rfc_ml_base': 6.91249256174731, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.10337814029936437}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:43:01,342] Trial 41 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.877114042913039, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.91386346514685, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9868114783279252}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:43:21,324] Trial 42 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.096544128130432, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.924353700831173, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8973578379487532}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:43:40,817] Trial 43 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.077193998322882, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.08081368467287, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.88529751289654}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:43:40,915] Trial 44 finished with value: 0.0 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'gbdt', 'lgbm_num_exp': 1, 'lgbm_num_base': 1.5883466005643836, 'lgbm_lr_exp': -1, 'lgbm_lr_base': 9.872714653055004, 'lgbm_maxdepth': 29, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 9.857766009014501, 'lgbm_mc_exp': 3, 'lgbm_mc_base': 9.64200448593618, 'lgbm_subsample': 0.5488804166695934, 'lgbm_lambda': 19.384438927090507, 'lgbm_alpha_exp': 1, 'lgbm_alpha_base': 1.080161213359963}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:44:00,870] Trial 45 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.120378643903939, 'rfc_maxdepth': 6, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.981061180856972, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9825454178729556}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:44:01,890] Trial 46 finished with value: 0.9421657095980311 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -3, 'xgb_eta_base': 9.780113617174809, 'mcw_exp': 2, 'mcw_base': 1.1311452710634864, 'xgb_maxdepth': 3, 'xgb_gamma': 9.677110591621656, 'xgb_subsample': 0.4073250532050893, 'xgb_lambda': 13.421713557516615, 'xgb_alpha': 6.373987744005668}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:44:18,161] Trial 47 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 7.426720792087079, 'rfc_maxdepth': 13, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.179700524535642, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8724459205511625}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:44:22,800] Trial 48 finished with value: 0.9438063986874488 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 2, 'rfc_num_base': 9.175977055403314, 'rfc_maxdepth': 5, 'rfc_ml_exp': 2, 'rfc_ml_base': 7.4391724091162, 'rfc_bootstrap': False}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:44:46,633] Trial 49 finished with value: 0.0 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -1, 'gbc_learn_base': 1.515929800913249, 'gbc_num_exp': 3, 'gbc_num_base': 9.937349281209528, 'gbc_subsample': 0.44703104961093076, 'gbc_ml_exp': 3, 'gbc_ml_base': 9.850552605425438, 'gbc_maxdepth': 26}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:44:46,801] Trial 50 finished with value: 0.5607054963084496 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'dart', 'lgbm_num_exp': 1, 'lgbm_num_base': 5.643982663388502, 'lgbm_lr_exp': -3, 'lgbm_lr_base': 1.0903408043189913, 'lgbm_maxdepth': 3, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 1.0084181516665618, 'lgbm_mc_exp': 3, 'lgbm_mc_base': 3.3491006259002694, 'lgbm_subsample': 0.12057697511564447, 'lgbm_lambda': 9.167425240457494, 'lgbm_alpha_exp': 1, 'lgbm_alpha_base': 7.576265587649889}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:45:08,468] Trial 51 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.966564760678443, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.980669542966044, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9750386276572951}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:45:28,700] Trial 52 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.384851231181248, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.47543179689076, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8977330800734865}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:45:50,912] Trial 53 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.982305671928602, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.263133424806227, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9140003716369995}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:46:11,035] Trial 54 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.192181655196114, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.376010392088412, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9898073277516775}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:46:31,151] Trial 55 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.206807115021574, 'rfc_maxdepth': 10, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.93915685321552, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.890077905218435}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:46:32,752] Trial 56 finished with value: 0.9930270713699754 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'dart', 'xgb_eta_exp': -2, 'xgb_eta_base': 1.4661118468854806, 'mcw_exp': -2, 'mcw_base': 4.91024728216543, 'xgb_maxdepth': 29, 'xgb_gamma': 2.9962451557291603, 'xgb_subsample': 0.5441134984909843, 'xgb_lambda': 10.246861057156655, 'xgb_alpha': 5.28555801949201}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:46:54,792] Trial 57 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.954424496062792, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.189712051408405, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9190439058293782}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:46:56,331] Trial 58 finished with value: 0.9934372436423298 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -3, 'gbc_learn_base': 9.696702178812746, 'gbc_num_exp': 1, 'gbc_num_base': 6.8222741541753695, 'gbc_subsample': 0.623125237402655, 'gbc_ml_exp': 1, 'gbc_ml_base': 5.809827492509209, 'gbc_maxdepth': 18}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:47:33,620] Trial 59 finished with value: 0.9721082854799016 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 7.632605022500412, 'rfc_maxdepth': 19, 'rfc_ml_exp': 1, 'rfc_ml_base': 9.06365069840865, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8446196043920802}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:47:33,770] Trial 60 finished with value: 0.9950779327317474 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'gbdt', 'lgbm_num_exp': 1, 'lgbm_num_base': 6.973200464416975, 'lgbm_lr_exp': -1, 'lgbm_lr_base': 4.5782420085368685, 'lgbm_maxdepth': 12, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 7.433992701552069, 'lgbm_mc_exp': 2, 'lgbm_mc_base': 4.742439579963917, 'lgbm_subsample': 0.9780219911230877, 'lgbm_lambda': 8.06734959021414, 'lgbm_alpha_exp': -1, 'lgbm_alpha_base': 6.83646019301342}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:47:54,454] Trial 61 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.498995522937749, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.951906039994519, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9796870557289052}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:48:15,961] Trial 62 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.94115898120436, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.52349330744829, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9280801932363303}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:48:35,959] Trial 63 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.30820261757382, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.973324308968877, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9346109678816036}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:48:56,306] Trial 64 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.447326478697176, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.377065540646491, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9289412486885371}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:48:57,763] Trial 65 finished with value: 0.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 2, 'rfc_num_base': 8.805004944650808, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.48548126836299, 'rfc_bootstrap': False}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:48:58,026] Trial 66 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 1, 'rfc_num_base': 9.437837581974168, 'rfc_maxdepth': 7, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.733005754357231, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.984867000694629}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:49:06,823] Trial 67 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 4.1183218958535255, 'rfc_maxdepth': 26, 'rfc_ml_exp': 3, 'rfc_ml_base': 4.1602184470595285, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8473364131367002}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:49:22,867] Trial 68 finished with value: 0.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.628310867962643, 'rfc_maxdepth': 4, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.488762783022594, 'rfc_bootstrap': False}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:49:27,602] Trial 69 finished with value: 0.9712879409351928 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -3, 'gbc_learn_base': 1.6023329483057975, 'gbc_num_exp': 3, 'gbc_num_base': 1.1854320854005413, 'gbc_subsample': 0.11302644881130364, 'gbc_ml_exp': 1, 'gbc_ml_base': 9.44461053463249, 'gbc_maxdepth': 14}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:49:28,105] Trial 70 finished with value: 0.9938474159146842 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -2, 'xgb_eta_base': 9.692482431197785, 'mcw_exp': 0, 'mcw_base': 4.392292860853663, 'xgb_maxdepth': 3, 'xgb_gamma': 4.159157359693575, 'xgb_subsample': 0.9688657837369434, 'xgb_lambda': 1.6913228250835672, 'xgb_alpha': 9.678069338947743}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:49:49,019] Trial 71 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.6174211156846, 'rfc_maxdepth': 7, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.983063634731838, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9866561547646453}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:50:10,819] Trial 72 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.949152643825453, 'rfc_maxdepth': 9, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.700481565326912, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9327127442665428}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:50:29,796] Trial 73 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.651908150496709, 'rfc_maxdepth': 12, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.498004308649517, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9345122106408603}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:51:04,055] Trial 74 finished with value: 0.9339622641509434 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.502014993226846, 'rfc_maxdepth': 6, 'rfc_ml_exp': 2, 'rfc_ml_base': 9.52635937317344, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9378714512408584}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:51:04,312] Trial 75 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 1, 'rfc_num_base': 8.774493899020491, 'rfc_maxdepth': 4, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.763295234765236, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.7175985352923566}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:51:24,772] Trial 76 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.584427956586525, 'rfc_maxdepth': 7, 'rfc_ml_exp': 3, 'rfc_ml_base': 7.97428640698692, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9440345940924669}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:51:28,343] Trial 77 finished with value: 0.9339622641509434 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 2, 'rfc_num_base': 9.975993664148282, 'rfc_maxdepth': 6, 'rfc_ml_exp': 2, 'rfc_ml_base': 9.58170782693474, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.868917925890878}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:51:29,704] Trial 78 finished with value: 0.8941755537325676 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'dart', 'lgbm_num_exp': 2, 'lgbm_num_base': 2.977393427165543, 'lgbm_lr_exp': -3, 'lgbm_lr_base': 7.463020873300069, 'lgbm_maxdepth': 30, 'lgbm_nl_exp': 2, 'lgbm_nl_base': 3.3319127288181405, 'lgbm_mc_exp': 3, 'lgbm_mc_base': 1.024608088651072, 'lgbm_subsample': 0.5061203129849637, 'lgbm_lambda': 1.1824634464152552, 'lgbm_alpha_exp': 1, 'lgbm_alpha_base': 9.693261086402176}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:51:48,416] Trial 79 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.842835784103976, 'rfc_maxdepth': 4, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.760830950003042, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8140827325021255}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:52:05,630] Trial 80 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.148948220899698, 'rfc_maxdepth': 4, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.589104723488466, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.7627041047848542}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:52:26,191] Trial 81 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.584613754169178, 'rfc_maxdepth': 28, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.320173608939793, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9470324752386473}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:52:45,488] Trial 82 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.949635955106801, 'rfc_maxdepth': 23, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.055623090835748, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.881529603452905}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:53:06,360] Trial 83 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.659958044459355, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.973511671518049, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.955188813864929}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:53:49,098] Trial 84 finished with value: 0.972518457752256 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.386370321315967, 'rfc_maxdepth': 18, 'rfc_ml_exp': 1, 'rfc_ml_base': 9.639632653612864, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9871330878017617}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:54:08,874] Trial 85 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.124828982797236, 'rfc_maxdepth': 16, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.034265176616756, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9005284437377946}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:54:09,343] Trial 86 finished with value: 0.9278096800656276 and parameters: {'algorithm': 'XGB', 'xgb_booster': 'gbtree', 'xgb_eta_exp': -3, 'xgb_eta_base': 3.981212634601742, 'mcw_exp': -1, 'mcw_base': 9.655793488983182, 'xgb_maxdepth': 21, 'xgb_gamma': 9.8164667860753, 'xgb_subsample': 0.12078099791107144, 'xgb_lambda': 19.46499913496097, 'xgb_alpha': 3.0922248340459695}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:54:25,994] Trial 87 finished with value: 0.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.987981749233153, 'rfc_maxdepth': 24, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.711154768040796, 'rfc_bootstrap': False}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:54:26,264] Trial 88 finished with value: 1.0 and parameters: {'algorithm': 'GBC', 'gbc_learn_exp': -1, 'gbc_learn_base': 4.2638441815305885, 'gbc_num_exp': 1, 'gbc_num_base': 9.983214820970996, 'gbc_subsample': 0.6718247393633653, 'gbc_ml_exp': 3, 'gbc_ml_base': 4.52287261181029, 'gbc_maxdepth': 21}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:54:46,682] Trial 89 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.520735264519905, 'rfc_maxdepth': 4, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.231152616413418, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9517120645481876}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:55:05,978] Trial 90 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.099121772000975, 'rfc_maxdepth': 6, 'rfc_ml_exp': 3, 'rfc_ml_base': 7.904511028416881, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8022550644714416}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:55:24,980] Trial 91 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.635009307610229, 'rfc_maxdepth': 4, 'rfc_ml_exp': 3, 'rfc_ml_base': 7.413763406291825, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.1851726359177513}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:55:43,113] Trial 92 finished with value: 0.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.188667637549903, 'rfc_maxdepth': 9, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.704035330144508, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.1349077123810682}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:56:00,670] Trial 93 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 8.43709487337114, 'rfc_maxdepth': 30, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.953580053753058, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.5005146253917396}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:56:21,415] Trial 94 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.742341077409211, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.23099442951346, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.8843343065162099}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:56:41,329] Trial 95 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.280871388950315, 'rfc_maxdepth': 6, 'rfc_ml_exp': 3, 'rfc_ml_base': 8.916163644779123, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9552646939762403}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:57:02,208] Trial 96 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.766344284067836, 'rfc_maxdepth': 21, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.680436893453155, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9008772595774133}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:57:02,302] Trial 97 finished with value: 0.9741591468416735 and parameters: {'algorithm': 'LGBM', 'lgbm_booster': 'gbdt', 'lgbm_num_exp': 1, 'lgbm_num_base': 1.1740381158638389, 'lgbm_lr_exp': -2, 'lgbm_lr_base': 3.4603521926648617, 'lgbm_maxdepth': 9, 'lgbm_nl_exp': 1, 'lgbm_nl_base': 7.260906843515781, 'lgbm_mc_exp': 2, 'lgbm_mc_base': 4.454215434247473, 'lgbm_subsample': 0.7380064857009577, 'lgbm_lambda': 10.410505703623267, 'lgbm_alpha_exp': 0, 'lgbm_alpha_base': 6.596296381522215}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:57:04,259] Trial 98 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 2, 'rfc_num_base': 8.977973399336344, 'rfc_maxdepth': 5, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.285791464287412, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9871744238204975}. Best is trial 26 with value: 1.0.
# [I 2023-06-05 17:57:25,685] Trial 99 finished with value: 1.0 and parameters: {'algorithm': 'RFC', 'rfc_num_exp': 3, 'rfc_num_base': 9.976221893972395, 'rfc_maxdepth': 3, 'rfc_ml_exp': 3, 'rfc_ml_base': 9.735138853444672, 'rfc_bootstrap': True, 'rfc_maxsamples': 0.9076288372715554}. Best is trial 26 with value: 1.0.

# %%
f_trials_rus = get_optuna_trials(study2, 100)
f_trials_rus
# Out:
# [(26,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.8410100557842,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.56629896082272,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9767807421240824})),
#  (27,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.51340671485012,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.752906804396432,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8924991091615007})),
#  (28,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.98704820722556,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.92358683139348,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9732463247600415})),
#  (29,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.94937577503255,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.980813233316885,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9611879579013174})),
#  (30,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.772331582616713,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.946466380862777,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.948691509968323})),
#  (31,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.850223156437691,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.941111602701715,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9588939360672871})),
#  (32,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.97225240764204,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.983484624258457,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9694654502813731})),
#  (33,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.808232813720277,
#     'rfc_maxdepth': 7,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.989534310974294,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9785731936826192})),
#  (36,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.234864166360003,
#     'rfc_maxdepth': 29,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.243881308143795,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8026075996563704})),
#  (40,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.60823396455368,
#     'rfc_maxdepth': 7,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 6.91249256174731,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.10337814029936437})),
#  (41,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.877114042913039,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.91386346514685,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9868114783279252})),
#  (42,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.096544128130432,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.924353700831173,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8973578379487532})),
#  (43,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.077193998322882,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.08081368467287,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.88529751289654})),
#  (45,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.120378643903939,
#     'rfc_maxdepth': 6,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.981061180856972,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9825454178729556})),
#  (47,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 7.426720792087079,
#     'rfc_maxdepth': 13,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.179700524535642,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8724459205511625})),
#  (51,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.966564760678443,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.980669542966044,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9750386276572951})),
#  (52,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.384851231181248,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.47543179689076,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8977330800734865})),
#  (53,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.982305671928602,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.263133424806227,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9140003716369995})),
#  (54,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.192181655196114,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.376010392088412,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9898073277516775})),
#  (55,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.206807115021574,
#     'rfc_maxdepth': 10,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.93915685321552,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.890077905218435})),
#  (57,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.954424496062792,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.189712051408405,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9190439058293782})),
#  (61,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.498995522937749,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.951906039994519,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9796870557289052})),
#  (62,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.94115898120436,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.52349330744829,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9280801932363303})),
#  (63,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.30820261757382,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.973324308968877,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9346109678816036})),
#  (64,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.447326478697176,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.377065540646491,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9289412486885371})),
#  (66,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 1,
#     'rfc_num_base': 9.437837581974168,
#     'rfc_maxdepth': 7,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.733005754357231,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.984867000694629})),
#  (67,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 4.1183218958535255,
#     'rfc_maxdepth': 26,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 4.1602184470595285,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8473364131367002})),
#  (71,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.6174211156846,
#     'rfc_maxdepth': 7,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.983063634731838,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9866561547646453})),
#  (72,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.949152643825453,
#     'rfc_maxdepth': 9,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.700481565326912,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9327127442665428})),
#  (73,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.651908150496709,
#     'rfc_maxdepth': 12,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.498004308649517,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9345122106408603})),
#  (75,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 1,
#     'rfc_num_base': 8.774493899020491,
#     'rfc_maxdepth': 4,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.763295234765236,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.7175985352923566})),
#  (76,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.584427956586525,
#     'rfc_maxdepth': 7,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 7.97428640698692,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9440345940924669})),
#  (79,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.842835784103976,
#     'rfc_maxdepth': 4,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.760830950003042,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8140827325021255})),
#  (80,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.148948220899698,
#     'rfc_maxdepth': 4,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.589104723488466,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.7627041047848542})),
#  (81,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.584613754169178,
#     'rfc_maxdepth': 28,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.320173608939793,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9470324752386473})),
#  (82,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.949635955106801,
#     'rfc_maxdepth': 23,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.055623090835748,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.881529603452905})),
#  (83,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.659958044459355,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.973511671518049,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.955188813864929})),
#  (85,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.124828982797236,
#     'rfc_maxdepth': 16,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.034265176616756,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9005284437377946})),
#  (88,
#   (1.0,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -1,
#     'gbc_learn_base': 4.2638441815305885,
#     'gbc_num_exp': 1,
#     'gbc_num_base': 9.983214820970996,
#     'gbc_subsample': 0.6718247393633653,
#     'gbc_ml_exp': 3,
#     'gbc_ml_base': 4.52287261181029,
#     'gbc_maxdepth': 21})),
#  (89,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.520735264519905,
#     'rfc_maxdepth': 4,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.231152616413418,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9517120645481876})),
#  (90,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.099121772000975,
#     'rfc_maxdepth': 6,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 7.904511028416881,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8022550644714416})),
#  (91,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.635009307610229,
#     'rfc_maxdepth': 4,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 7.413763406291825,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.1851726359177513})),
#  (93,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.43709487337114,
#     'rfc_maxdepth': 30,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.953580053753058,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.5005146253917396})),
#  (94,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.742341077409211,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.23099442951346,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8843343065162099})),
#  (95,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.280871388950315,
#     'rfc_maxdepth': 6,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.916163644779123,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9552646939762403})),
#  (96,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.766344284067836,
#     'rfc_maxdepth': 21,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.680436893453155,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9008772595774133})),
#  (98,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 2,
#     'rfc_num_base': 8.977973399336344,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.285791464287412,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9871744238204975})),
#  (99,
#   (1.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.976221893972395,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.735138853444672,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9076288372715554})),
#  (13,
#   (0.9979491386382281,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 8.884648136555981})),
#  (14,
#   (0.9979491386382281,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.780451107797834})),
#  (15,
#   (0.9979491386382281,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.878508102046183})),
#  (16,
#   (0.9979491386382281,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.855265500252118})),
#  (19,
#   (0.9979491386382281,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 7.676328365338093})),
#  (21,
#   (0.9979491386382281,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.851760079713124})),
#  (22,
#   (0.9979491386382281,
#    {'algorithm': 'GNB', 'gnb_exp': 10, 'gnb_base': 9.89310147030969})),
#  (17,
#   (0.9975389663658737,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.122436978759456})),
#  (18,
#   (0.9975389663658737,
#    {'algorithm': 'GNB', 'gnb_exp': 8, 'gnb_base': 2.4086726951456945})),
#  (20,
#   (0.9975389663658737,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 7.3699500279488035})),
#  (23,
#   (0.9975389663658737,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 8.61786263550669})),
#  (25,
#   (0.9975389663658737,
#    {'algorithm': 'GNB', 'gnb_exp': 9, 'gnb_base': 6.527882068855613})),
#  (6,
#   (0.9971287940935193,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -2,
#     'gbc_learn_base': 6.102829507416073,
#     'gbc_num_exp': 2,
#     'gbc_num_base': 4.361893013438007,
#     'gbc_subsample': 0.9123910040725568,
#     'gbc_ml_exp': 2,
#     'gbc_ml_base': 2.9468171812720865,
#     'gbc_maxdepth': 7})),
#  (5,
#   (0.9967186218211649,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'goss',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 4.7857861825870565,
#     'lgbm_lr_exp': -2,
#     'lgbm_lr_base': 4.645201530116562,
#     'lgbm_maxdepth': 17,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 5.409294209476331,
#     'lgbm_mc_exp': 1,
#     'lgbm_mc_base': 7.1383417313592705,
#     'lgbm_subsample': 0.3342514284740086,
#     'lgbm_lambda': 4.695611551685067,
#     'lgbm_alpha_exp': -1,
#     'lgbm_alpha_base': 4.448228031091103})),
#  (9,
#   (0.9958982772764561,
#    {'algorithm': 'GNB', 'gnb_exp': 7, 'gnb_base': 4.884372250771577})),
#  (0,
#   (0.9950779327317474,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'dart',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 9.222876306126139,
#     'lgbm_lr_exp': -1,
#     'lgbm_lr_base': 6.31245941173835,
#     'lgbm_maxdepth': 22,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 9.938072043465244,
#     'lgbm_mc_exp': 1,
#     'lgbm_mc_base': 7.117969420544642,
#     'lgbm_subsample': 0.9115048669842948,
#     'lgbm_lambda': 14.104046492032666,
#     'lgbm_alpha_exp': 0,
#     'lgbm_alpha_base': 9.595196727728482})),
#  (4,
#   (0.9950779327317474,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -1,
#     'xgb_eta_base': 5.412002301915272,
#     'mcw_exp': 0,
#     'mcw_base': 1.1839028414503587,
#     'xgb_maxdepth': 15,
#     'xgb_gamma': 6.563230215488427,
#     'xgb_subsample': 0.7891609078773494,
#     'xgb_lambda': 3.1136549805177576,
#     'xgb_alpha': 2.334761463110836})),
#  (11,
#   (0.9950779327317474,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'goss',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 2.5846136055063313,
#     'lgbm_lr_exp': -2,
#     'lgbm_lr_base': 9.418898465997744,
#     'lgbm_maxdepth': 3,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 5.390793703096259,
#     'lgbm_mc_exp': 1,
#     'lgbm_mc_base': 1.7872627634524672,
#     'lgbm_subsample': 0.23720843352242912,
#     'lgbm_lambda': 1.817053958480658,
#     'lgbm_alpha_exp': -1,
#     'lgbm_alpha_base': 4.253494652234595})),
#  (60,
#   (0.9950779327317474,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'gbdt',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 6.973200464416975,
#     'lgbm_lr_exp': -1,
#     'lgbm_lr_base': 4.5782420085368685,
#     'lgbm_maxdepth': 12,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 7.433992701552069,
#     'lgbm_mc_exp': 2,
#     'lgbm_mc_base': 4.742439579963917,
#     'lgbm_subsample': 0.9780219911230877,
#     'lgbm_lambda': 8.06734959021414,
#     'lgbm_alpha_exp': -1,
#     'lgbm_alpha_base': 6.83646019301342})),
#  (24,
#   (0.9938474159146842,
#    {'algorithm': 'GNB', 'gnb_exp': 6, 'gnb_base': 8.746155743833311})),
#  (70,
#   (0.9938474159146842,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -2,
#     'xgb_eta_base': 9.692482431197785,
#     'mcw_exp': 0,
#     'mcw_base': 4.392292860853663,
#     'xgb_maxdepth': 3,
#     'xgb_gamma': 4.159157359693575,
#     'xgb_subsample': 0.9688657837369434,
#     'xgb_lambda': 1.6913228250835672,
#     'xgb_alpha': 9.678069338947743})),
#  (10,
#   (0.9934372436423298,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -3,
#     'gbc_learn_base': 3.379274289619472,
#     'gbc_num_exp': 1,
#     'gbc_num_base': 7.759464032322617,
#     'gbc_subsample': 0.9464706813274,
#     'gbc_ml_exp': 1,
#     'gbc_ml_base': 6.3770697320234895,
#     'gbc_maxdepth': 5})),
#  (58,
#   (0.9934372436423298,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -3,
#     'gbc_learn_base': 9.696702178812746,
#     'gbc_num_exp': 1,
#     'gbc_num_base': 6.8222741541753695,
#     'gbc_subsample': 0.623125237402655,
#     'gbc_ml_exp': 1,
#     'gbc_ml_base': 5.809827492509209,
#     'gbc_maxdepth': 18})),
#  (56,
#   (0.9930270713699754,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -2,
#     'xgb_eta_base': 1.4661118468854806,
#     'mcw_exp': -2,
#     'mcw_base': 4.91024728216543,
#     'xgb_maxdepth': 29,
#     'xgb_gamma': 2.9962451557291603,
#     'xgb_subsample': 0.5441134984909843,
#     'xgb_lambda': 10.246861057156655,
#     'xgb_alpha': 5.28555801949201})),
#  (3,
#   (0.9901558654634947,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -1,
#     'xgb_eta_base': 6.869577585427217,
#     'mcw_exp': 1,
#     'mcw_base': 7.030064614239413,
#     'xgb_maxdepth': 12,
#     'xgb_gamma': 7.687997946651469,
#     'xgb_subsample': 0.910115606681263,
#     'xgb_lambda': 6.052733637985947,
#     'xgb_alpha': 9.988233992888603})),
#  (12,
#   (0.9790812141099262,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -2,
#     'gbc_learn_base': 6.190772754853172,
#     'gbc_num_exp': 2,
#     'gbc_num_base': 1.2629550840656836,
#     'gbc_subsample': 0.9999447921014333,
#     'gbc_ml_exp': 3,
#     'gbc_ml_base': 2.3368434101055677,
#     'gbc_maxdepth': 5})),
#  (2,
#   (0.9782608695652174,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'goss',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 8.953346727520703,
#     'lgbm_lr_exp': -3,
#     'lgbm_lr_base': 1.1045774681480909,
#     'lgbm_maxdepth': 16,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 1.1110458863092152,
#     'lgbm_mc_exp': 2,
#     'lgbm_mc_base': 8.11876539639625,
#     'lgbm_subsample': 0.7408566211269251,
#     'lgbm_lambda': 15.848542699553548,
#     'lgbm_alpha_exp': 0,
#     'lgbm_alpha_base': 2.7083881577959437})),
#  (8,
#   (0.9741591468416735,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 2,
#     'rfc_num_base': 1.647484696927805,
#     'rfc_maxdepth': 20,
#     'rfc_ml_exp': 1,
#     'rfc_ml_base': 5.448050020639872,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.4954497338457835})),
#  (97,
#   (0.9741591468416735,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'gbdt',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 1.1740381158638389,
#     'lgbm_lr_exp': -2,
#     'lgbm_lr_base': 3.4603521926648617,
#     'lgbm_maxdepth': 9,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 7.260906843515781,
#     'lgbm_mc_exp': 2,
#     'lgbm_mc_base': 4.454215434247473,
#     'lgbm_subsample': 0.7380064857009577,
#     'lgbm_lambda': 10.410505703623267,
#     'lgbm_alpha_exp': 0,
#     'lgbm_alpha_base': 6.596296381522215})),
#  (84,
#   (0.972518457752256,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.386370321315967,
#     'rfc_maxdepth': 18,
#     'rfc_ml_exp': 1,
#     'rfc_ml_base': 9.639632653612864,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9871330878017617})),
#  (59,
#   (0.9721082854799016,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 7.632605022500412,
#     'rfc_maxdepth': 19,
#     'rfc_ml_exp': 1,
#     'rfc_ml_base': 9.06365069840865,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8446196043920802})),
#  (69,
#   (0.9712879409351928,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -3,
#     'gbc_learn_base': 1.6023329483057975,
#     'gbc_num_exp': 3,
#     'gbc_num_base': 1.1854320854005413,
#     'gbc_subsample': 0.11302644881130364,
#     'gbc_ml_exp': 1,
#     'gbc_ml_base': 9.44461053463249,
#     'gbc_maxdepth': 14})),
#  (48,
#   (0.9438063986874488,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 2,
#     'rfc_num_base': 9.175977055403314,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 2,
#     'rfc_ml_base': 7.4391724091162,
#     'rfc_bootstrap': False})),
#  (46,
#   (0.9421657095980311,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -3,
#     'xgb_eta_base': 9.780113617174809,
#     'mcw_exp': 2,
#     'mcw_base': 1.1311452710634864,
#     'xgb_maxdepth': 3,
#     'xgb_gamma': 9.677110591621656,
#     'xgb_subsample': 0.4073250532050893,
#     'xgb_lambda': 13.421713557516615,
#     'xgb_alpha': 6.373987744005668})),
#  (35,
#   (0.9360131255127153,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 2,
#     'rfc_num_base': 8.166167232881081,
#     'rfc_maxdepth': 8,
#     'rfc_ml_exp': 2,
#     'rfc_ml_base': 8.245076635550074,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.7646405679867878})),
#  (39,
#   (0.9360131255127153,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 2,
#     'rfc_num_base': 8.422969973942001,
#     'rfc_maxdepth': 8,
#     'rfc_ml_exp': 2,
#     'rfc_ml_base': 8.865426604190802,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.8392322658625766})),
#  (34,
#   (0.9356029532403609,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 8.510574903232618,
#     'rfc_maxdepth': 10,
#     'rfc_ml_exp': 2,
#     'rfc_ml_base': 8.363112535107176,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.7742683478316066})),
#  (74,
#   (0.9339622641509434,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.502014993226846,
#     'rfc_maxdepth': 6,
#     'rfc_ml_exp': 2,
#     'rfc_ml_base': 9.52635937317344,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.9378714512408584})),
#  (77,
#   (0.9339622641509434,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 2,
#     'rfc_num_base': 9.975993664148282,
#     'rfc_maxdepth': 6,
#     'rfc_ml_exp': 2,
#     'rfc_ml_base': 9.58170782693474,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.868917925890878})),
#  (86,
#   (0.9278096800656276,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'gbtree',
#     'xgb_eta_exp': -3,
#     'xgb_eta_base': 3.981212634601742,
#     'mcw_exp': -1,
#     'mcw_base': 9.655793488983182,
#     'xgb_maxdepth': 21,
#     'xgb_gamma': 9.8164667860753,
#     'xgb_subsample': 0.12078099791107144,
#     'xgb_lambda': 19.46499913496097,
#     'xgb_alpha': 3.0922248340459695})),
#  (37,
#   (0.9273995077932732,
#    {'algorithm': 'XGB',
#     'xgb_booster': 'dart',
#     'xgb_eta_exp': -3,
#     'xgb_eta_base': 1.5939530693409836,
#     'mcw_exp': -2,
#     'mcw_base': 9.911642937121965,
#     'xgb_maxdepth': 29,
#     'xgb_gamma': 0.08633898085273373,
#     'xgb_subsample': 0.10401373058306107,
#     'xgb_lambda': 19.912301934032435,
#     'xgb_alpha': 0.0015819424207190735})),
#  (78,
#   (0.8941755537325676,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'dart',
#     'lgbm_num_exp': 2,
#     'lgbm_num_base': 2.977393427165543,
#     'lgbm_lr_exp': -3,
#     'lgbm_lr_base': 7.463020873300069,
#     'lgbm_maxdepth': 30,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 3.3319127288181405,
#     'lgbm_mc_exp': 3,
#     'lgbm_mc_base': 1.024608088651072,
#     'lgbm_subsample': 0.5061203129849637,
#     'lgbm_lambda': 1.1824634464152552,
#     'lgbm_alpha_exp': 1,
#     'lgbm_alpha_base': 9.693261086402176})),
#  (1,
#   (0.8634126333059885,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 1,
#     'rfc_num_base': 5.92402539190864,
#     'rfc_maxdepth': 15,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 2.6294668846878064,
#     'rfc_bootstrap': False})),
#  (7,
#   (0.8338802296964725,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -1,
#     'gbc_learn_base': 8.693223906481471,
#     'gbc_num_exp': 3,
#     'gbc_num_base': 3.8636901404617845,
#     'gbc_subsample': 0.14686850908415763,
#     'gbc_ml_exp': 2,
#     'gbc_ml_base': 2.0377166804912665,
#     'gbc_maxdepth': 29})),
#  (50,
#   (0.5607054963084496,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'dart',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 5.643982663388502,
#     'lgbm_lr_exp': -3,
#     'lgbm_lr_base': 1.0903408043189913,
#     'lgbm_maxdepth': 3,
#     'lgbm_nl_exp': 2,
#     'lgbm_nl_base': 1.0084181516665618,
#     'lgbm_mc_exp': 3,
#     'lgbm_mc_base': 3.3491006259002694,
#     'lgbm_subsample': 0.12057697511564447,
#     'lgbm_lambda': 9.167425240457494,
#     'lgbm_alpha_exp': 1,
#     'lgbm_alpha_base': 7.576265587649889})),
#  (38,
#   (0.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.986446112095006,
#     'rfc_maxdepth': 3,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 8.636784707559762,
#     'rfc_bootstrap': False})),
#  (44,
#   (0.0,
#    {'algorithm': 'LGBM',
#     'lgbm_booster': 'gbdt',
#     'lgbm_num_exp': 1,
#     'lgbm_num_base': 1.5883466005643836,
#     'lgbm_lr_exp': -1,
#     'lgbm_lr_base': 9.872714653055004,
#     'lgbm_maxdepth': 29,
#     'lgbm_nl_exp': 1,
#     'lgbm_nl_base': 9.857766009014501,
#     'lgbm_mc_exp': 3,
#     'lgbm_mc_base': 9.64200448593618,
#     'lgbm_subsample': 0.5488804166695934,
#     'lgbm_lambda': 19.384438927090507,
#     'lgbm_alpha_exp': 1,
#     'lgbm_alpha_base': 1.080161213359963})),
#  (49,
#   (0.0,
#    {'algorithm': 'GBC',
#     'gbc_learn_exp': -1,
#     'gbc_learn_base': 1.515929800913249,
#     'gbc_num_exp': 3,
#     'gbc_num_base': 9.937349281209528,
#     'gbc_subsample': 0.44703104961093076,
#     'gbc_ml_exp': 3,
#     'gbc_ml_base': 9.850552605425438,
#     'gbc_maxdepth': 26})),
#  (65,
#   (0.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 2,
#     'rfc_num_base': 8.805004944650808,
#     'rfc_maxdepth': 5,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.48548126836299,
#     'rfc_bootstrap': False})),
#  (68,
#   (0.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.628310867962643,
#     'rfc_maxdepth': 4,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.488762783022594,
#     'rfc_bootstrap': False})),
#  (87,
#   (0.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.987981749233153,
#     'rfc_maxdepth': 24,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.711154768040796,
#     'rfc_bootstrap': False})),
#  (92,
#   (0.0,
#    {'algorithm': 'RFC',
#     'rfc_num_exp': 3,
#     'rfc_num_base': 9.188667637549903,
#     'rfc_maxdepth': 9,
#     'rfc_ml_exp': 3,
#     'rfc_ml_base': 9.704035330144508,
#     'rfc_bootstrap': True,
#     'rfc_maxsamples': 0.1349077123810682}))]

# %%
#SAVE THE RUS TRIALS
pickle_list = [f_trials_rus]
f = open('optuna_trials_rus.pckl','wb')
pickle.dump(pickle_list,f)
f.close()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# EXTRA CODE NOT BEING USED

# %%
# def optimize_rus(trial):
    
#     #Read in the data needed for each experiment
#     data = get_rus_data() #[Xtrain_rus, Xdev_rus, ytrain_rus, ydev_rus]
#     X_train = data[0]
#     X_dev = data[1]
#     y_train = data[2]
#     y_dev = data[3]
    
#     #Use Optuna to find the best algorithm to use
#     algorithm = trial.suggest_categorical('algorithm', ['XGB', 'LGBM', 'GNB', 'RFC', 'GBC'])
    
#     # XGBoost Classifier
#     if algorithm == 'XGB':
#         #Have Optuna suggest values for the following hyperparameters
#         xgb_booster = trial.suggest_categorical('xgb_booster', ['gbtree','dart'])
#         xgb_eta = trial.suggest_float('xgb_eta', 0.01, 0.99)
#         xgb_mcw = trial.suggest_float('xgb_mcw', 0.01, 100.0)
#         xgb_maxdepth = trial.suggest_int('xgb_maxdepth', 3, 30)
#         xgb_gamma = trial.suggest_float('xgb_gamma', 0.0, 10.0)
#         xgb_subsample = trial.suggest_float('xgb_subsample', 0.1, 1.0)
#         xgb_lambda = trial.suggest_float('xgb_lambda', 1.0, 20.0)
#         xgb_alpha = trial.suggest_float('xgb_alpha', 0.0, 10.0)
        
#         #Create the model
#         model = XGBClassifier(booster=xgb_booster, eta=xgb_eta, min_child_weight=xgb_mcw,
#                              max_depth=xgb_maxdepth, gamma=xgb_gamma, subsample=xgb_subsample,
#                              reg_lambda=xgb_lambda, reg_alpha=xgb_alpha, random_state=10)
    
#     # LGBM Classifier
#     elif algorithm == 'LGBM':
#         #Have Optuna suggest values for the following hyperparameters
#         lgbm_boosting = trial.suggest_categorical('lgbm_booster', ['gbdt','dart','goss'])
#         lgbm_num = trial.suggest_int('lgbm_num', 10, 500)
#         lgbm_learningrate = trial.suggest_float('lgbm_learningrate',0.01,0.99)
#         lgbm_maxdepth = trial.suggest_int('lgbm_maxdepth', 3, 30)
#         lgbm_numleaves = trial.suggest_int('lgbm_numleaves',20, 500)
#         lgbm_minsamples = trial.suggest_float('lgbm_minsamples', 50, 2500)
#         lgbm_subsample = trial.suggest_float('lgbm_subsample', 0.1, 1.0)
#         lgbm_lambda = trial.suggest_float('lgbm_lambda', 1.0, 20.0)
#         lgbm_alpha = trial.suggest_float('lgbm_alpha', 0.0, 10.0)
        
#         #Create the model
#         model = LGBMClassifier(boosting_type=lgbm_boosting, num_iterations=lgbm_num,
#                               learning_rate=lgbm_learningrate, max_depth=lgbm_maxdepth,
#                               num_leaves=lgbm_numleaves,min_child_samples=lgbm_minsamples, 
#                               subsample=lgbm_subsample,reg_lambda=lgbm_lambda, reg_alpha=lgbm_alpha, 
#                               random_state=10)
        
        
#     # Gaussian Naive Bayes
#     elif algorithm == 'GNB':
#         #Have Optuna suggest a value for var_smoothing
#         gnb_exp = trial.suggest_int('gnb_exp',6,9)
#         gnb_base = trial.suggest_float(0.1, 1.0)
#         gnb_varsmoothing = gnb_base * (10**(-gnb_exp))
        
#         #Create the model
#         model = GaussianNB(var_smoothing=gnb_varsmoothing)
        
#     # Random Forest Classifier
#     elif algorithm == 'RFC':
#         #Have Optuna suggest values for the following hyperparameters
#         rfc_num = trial.suggest_int('rfc_num', 10, 1000)
#         rfc_maxdepth = trial.suggest_int('rfc_maxdepth', 3, 30)
#         rfc_minleaf = trial.suggest_int('rfc_minleaf', 50, 2500)
#         rfc_bootstrap = trial.suggest_categorical('rfc_bootstrap',True, False)
        
#         #Create the model
#         if rfc_bootstrap == False:
#             model = RandomForestClassifier(n_estimators = rfc_num, max_depth=rfc_maxdepth,
#                                           min_samples_leaf=rfc_minleaf, bootstrap=rfc_bootstrap,
#                                           random_state=10)
#         else:
#             rfc_maxsamples = trial.suggest_float('rfc_maxsamples',0.1,0.99)
#             model = RandomForestClassifier(n_estimators = rfc_num, max_depth=rfc_maxdepth,
#                                           min_samples_leaf=rfc_minleaf, bootstrap=rfc_bootstrap,
#                                           max_samples=rfc_maxsamples,random_state=10)
    
#     else:
#         #Have Optuna suggest values for the following hyperparameters
#         gbc_learning = trial.suggest_float('gbc_learning',0.01,0.99)
#         gbc_num = trial.suggest_int('gbc_num', 10, 1000)
#         gbc_subsample = trial.suggest_float('gbc_subsample', 0.1, 1.0)
#         gbc_minleaf = trial.suggest_int('gbc_minleaf', 50, 2500)
#         gbc_maxdepth = trial.suggest_int('rfc_maxdepth', 3, 30)
        
#         #Create the model
#         model = GradientBoostingClassifier(learning_rate=gbc_learning, n_estimators=gbc_num,
#                                           subsample=gbc_subsample,min_samples_leaf=gbc_minleaf, 
#                                           max_depth=gbc_maxdepth,random_state=10)
    
#     #Fit and score model
#     model.fit(X_train, y_train)
#     score_recall = recall_score(y_true=y_dev, y_pred=model.predict(X_dev), pos_label=1)
    
#     #Return Score
#     return score_recall
